# %%
#Import all the libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from functools import reduce
import math
import urllib
import difflib 
import seaborn as sns
import sklearn.model_selection
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Step One
# ### First we must load the data we previously prepared from the 'Data Loading' notebook, QS 2023 university ranking data.

# %%
'''Loads the dataframe of the spreadsheets with the data all together'''
df_All_Companies_merged = pd. read_pickle(r'Data\df_All_Companies_merged.pkl')
df_Successful_merged = pd. read_pickle(r'Data\df_SuccessfulInvestor_merged.pkl')

# %%
X = pd.DataFrame(df_All_Companies_merged).to_numpy()

# %%
X[0,:]
# Out:
# array(['Weller', 'welleryou.com', Timestamp('2018-01-01 00:00:00'),
#        'Boulder', 'Food and Beverage,Wellness',
#        'Food and Beverage,Health Care',
#        'Weller is a CBD-infused snack and beverage maker.',
#        'Great Oaks Venture Capital,Harrison Metal', nan, nan, nan, nan,
#        nan, 'Third Street Chai,Weller,Weller',
#        'Co-Founder,Co-Founder,Founder/CEO', 1], dtype=object)

# %%
#Importing importing QS university ranking data
df_University_Rankings = pd.read_excel(r'Data/2022_QS_World_University_Rankings_Results_public_version_modified.xlsx')

# %% [markdown]
# ## City

# %%
temp = df_Successful_merged['city'].values[:].tolist()
list_all_city_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]
list_all_city_unfiltered = reduce(lambda x,y :x+y ,list_all_city_unfiltered)
list_all_city = list(set(list_all_city_unfiltered))
list_all_city_and_count = [[0,x] for x in list_all_city]

for x in list_all_city_unfiltered:
    idx = list_all_city.index(x)
    list_all_city_and_count[idx][0] += 1

list_all_city_and_count.sort(reverse=True)

for idx, value in enumerate(list_all_city_and_count):
    if idx == 30: break
    print('The top {} city is {} occuring {} times'.format(idx + 1, value[1], value[0] ))
# Out:
# The top 1 city is San Francisco occuring 1017 times
# The top 2 city is New York occuring 530 times
# The top 3 city is Los Angeles occuring 119 times
# The top 4 city is Palo Alto occuring 115 times
# The top 5 city is Boston occuring 85 times
# The top 6 city is Mountain View occuring 60 times
# The top 7 city is Brooklyn occuring 55 times
# The top 8 city is San Mateo occuring 48 times
# The top 9 city is Seattle occuring 47 times
# The top 10 city is Cambridge occuring 37 times
# The top 11 city is Austin occuring 37 times
# The top 12 city is Redwood City occuring 36 times
# The top 13 city is Santa Monica occuring 35 times
# The top 14 city is Oakland occuring 28 times
# The top 15 city is Chicago occuring 26 times
# The top 16 city is San Jose occuring 25 times
# The top 17 city is Menlo Park occuring 25 times
# The top 18 city is Washington occuring 20 times
# The top 19 city is Santa Clara occuring 20 times
# The top 20 city is Berkeley occuring 20 times
# The top 21 city is San Diego occuring 16 times
# The top 22 city is Denver occuring 14 times
# The top 23 city is Venice occuring 12 times
# The top 24 city is Portland occuring 12 times
# The top 25 city is Atlanta occuring 12 times
# The top 26 city is Sunnyvale occuring 11 times
# The top 27 city is Philadelphia occuring 11 times
# The top 28 city is Burlingame occuring 11 times
# The top 29 city is Boulder occuring 11 times
# The top 30 city is Miami occuring 10 times

# %% [markdown]
# ## Category list

# %%
temp = df_Successful_merged['category_list'].values[:].tolist()
list_all_category_list_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]
list_all_category_list_unfiltered = reduce(lambda x,y :x+y ,list_all_category_list_unfiltered)
list_all_category_list = list(set(list_all_category_list_unfiltered))
list_all_category_list_and_count = [[0,x] for x in list_all_category_list]

for x in list_all_category_list_unfiltered:
    idx = list_all_category_list.index(x)
    list_all_category_list_and_count[idx][0] += 1

list_all_category_list_and_count.sort(reverse=True)

for idx, value in enumerate(list_all_category_list_and_count):
    if idx == 35: break
    print('The top {} category list is {} occuring {} times'.format(idx + 1, value[1], value[0] ))
# Out:
# The top 1 category list is Software occuring 834 times
# The top 2 category list is Information Technology occuring 330 times
# The top 3 category list is Health Care occuring 312 times
# The top 4 category list is E-Commerce occuring 290 times
# The top 5 category list is Internet occuring 277 times
# The top 6 category list is SaaS occuring 276 times
# The top 7 category list is FinTech occuring 266 times
# The top 8 category list is Mobile occuring 238 times
# The top 9 category list is Artificial Intelligence occuring 235 times
# The top 10 category list is Financial Services occuring 232 times
# The top 11 category list is Enterprise Software occuring 211 times
# The top 12 category list is Analytics occuring 191 times
# The top 13 category list is Apps occuring 180 times
# The top 14 category list is Machine Learning occuring 176 times
# The top 15 category list is Finance occuring 131 times
# The top 16 category list is Big Data occuring 119 times
# The top 17 category list is Education occuring 113 times
# The top 18 category list is Marketplace occuring 112 times
# The top 19 category list is Mobile Apps occuring 106 times
# The top 20 category list is Biotechnology occuring 96 times
# The top 21 category list is Real Estate occuring 95 times
# The top 22 category list is Wellness occuring 92 times
# The top 23 category list is Social Media occuring 84 times
# The top 24 category list is Medical occuring 84 times
# The top 25 category list is Retail occuring 79 times
# The top 26 category list is Blockchain occuring 77 times
# The top 27 category list is Payments occuring 75 times
# The top 28 category list is Human Resources occuring 73 times
# The top 29 category list is Security occuring 69 times
# The top 30 category list is Cryptocurrency occuring 65 times
# The top 31 category list is Cloud Computing occuring 65 times
# The top 32 category list is Fashion occuring 64 times
# The top 33 category list is Food and Beverage occuring 62 times
# The top 34 category list is Computer occuring 62 times
# The top 35 category list is Advertising occuring 62 times

# %% [markdown]
# ## Category list group

# %%
temp = df_Successful_merged['category_groups_list'].values[:].tolist()
list_all_category_groups_list_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]
list_all_category_groups_list_unfiltered = reduce(lambda x,y :x+y ,list_all_category_groups_list_unfiltered)
list_all_category_groups_list = list(set(list_all_category_groups_list_unfiltered))
list_all_category_groups_list_and_count = [[0,x] for x in list_all_category_groups_list]

for x in list_all_category_groups_list_unfiltered:
    idx = list_all_category_groups_list.index(x)
    list_all_category_groups_list_and_count[idx][0] += 1

list_all_category_groups_list_and_count.sort(reverse=True)

for idx, value in enumerate(list_all_category_groups_list_and_count):
    if idx == 35: break
    print('The top {} category groups list is {} occuring {} times'.format(idx + 1, value[1], value[0] ))
# Out:
# The top 1 category groups list is Software occuring 1609 times
# The top 2 category groups list is Information Technology occuring 653 times
# The top 3 category groups list is Internet Services occuring 646 times
# The top 4 category groups list is Data and Analytics occuring 571 times
# The top 5 category groups list is Financial Services occuring 514 times
# The top 6 category groups list is Other occuring 442 times
# The top 7 category groups list is Commerce and Shopping occuring 439 times
# The top 8 category groups list is Health Care occuring 416 times
# The top 9 category groups list is Science and Engineering occuring 414 times
# The top 10 category groups list is Mobile occuring 393 times
# The top 11 category groups list is Hardware occuring 375 times
# The top 12 category groups list is Media and Entertainment occuring 341 times
# The top 13 category groups list is Artificial Intelligence occuring 301 times
# The top 14 category groups list is Apps occuring 295 times
# The top 15 category groups list is Sales and Marketing occuring 227 times
# The top 16 category groups list is Professional Services occuring 223 times
# The top 17 category groups list is Community and Lifestyle occuring 211 times
# The top 18 category groups list is Transportation occuring 186 times
# The top 19 category groups list is Real Estate occuring 184 times
# The top 20 category groups list is Payments occuring 175 times
# The top 21 category groups list is Design occuring 163 times
# The top 22 category groups list is Consumer Electronics occuring 147 times
# The top 23 category groups list is Privacy and Security occuring 145 times
# The top 24 category groups list is Administrative Services occuring 144 times
# The top 25 category groups list is Education occuring 140 times
# The top 26 category groups list is Consumer Goods occuring 121 times
# The top 27 category groups list is Food and Beverage occuring 117 times
# The top 28 category groups list is Content and Publishing occuring 112 times
# The top 29 category groups list is Biotechnology occuring 108 times
# The top 30 category groups list is Sports occuring 99 times
# The top 31 category groups list is Lending and Investments occuring 91 times
# The top 32 category groups list is Video occuring 89 times
# The top 33 category groups list is Messaging and Telecommunications occuring 89 times
# The top 34 category groups list is Travel and Tourism occuring 78 times
# The top 35 category groups list is Advertising occuring 72 times

# %% [markdown]
# ## All_seed_investors

# %%
temp = df_Successful_merged['all_seed_investors'].values[:].tolist()
list_all_seed_investors_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]
list_all_seed_investors_unfiltered = reduce(lambda x,y :x+y ,list_all_seed_investors_unfiltered)
list_all_seed_investors = list(set(list_all_seed_investors_unfiltered))
list_all_seed_investors_and_count = [[0,x] for x in list_all_seed_investors]

for x in list_all_seed_investors_unfiltered:
    idx = list_all_seed_investors.index(x)
    list_all_seed_investors_and_count[idx][0] += 1

list_all_seed_investors_and_count.sort(reverse=True)

for idx, value in enumerate(list_all_seed_investors_and_count):
    if idx == 35: break
    print('The top {} all seed investor is {} occuring {} times'.format(idx + 1, value[1], value[0] ))
# Out:
# The top 1 all seed investor is SV Angel occuring 539 times
# The top 2 all seed investor is BoxGroup occuring 248 times
# The top 3 all seed investor is Great Oaks Venture Capital occuring 196 times
# The top 4 all seed investor is Soma Capital occuring 177 times
# The top 5 all seed investor is Initialized Capital occuring 171 times
# The top 6 all seed investor is DCVC occuring 154 times
# The top 7 all seed investor is Tuesday Capital occuring 127 times
# The top 8 all seed investor is Ulu Ventures occuring 122 times
# The top 9 all seed investor is RRE Ventures occuring 114 times
# The top 10 all seed investor is Wei Guo occuring 109 times
# The top 11 all seed investor is Accel occuring 106 times
# The top 12 all seed investor is Acequia Capital (AceCap) occuring 100 times
# The top 13 all seed investor is Abstract Ventures occuring 99 times
# The top 14 all seed investor is Accomplice occuring 85 times
# The top 15 all seed investor is Susa Ventures occuring 82 times
# The top 16 all seed investor is Scott Belsky occuring 82 times
# The top 17 all seed investor is Pear VC occuring 81 times
# The top 18 all seed investor is Haystack occuring 78 times
# The top 19 all seed investor is NextView Ventures occuring 76 times
# The top 20 all seed investor is UpHonest Capital occuring 73 times
# The top 21 all seed investor is Kevin Moore occuring 71 times
# The top 22 all seed investor is Digital Currency Group occuring 67 times
# The top 23 all seed investor is Amino Capital occuring 67 times
# The top 24 all seed investor is Harrison Metal occuring 65 times
# The top 25 all seed investor is Canaan Partners occuring 59 times
# The top 26 all seed investor is Rothenberg Ventures occuring 57 times
# The top 27 all seed investor is Graph Ventures occuring 57 times
# The top 28 all seed investor is Kevin Mahaffey occuring 54 times
# The top 29 all seed investor is Expansion Venture Capital occuring 52 times
# The top 30 all seed investor is Lee Linden occuring 50 times
# The top 31 all seed investor is ACE & Company occuring 49 times
# The top 32 all seed investor is Tim Draper occuring 48 times
# The top 33 all seed investor is Atlas Venture occuring 48 times
# The top 34 all seed investor is Spark Capital occuring 44 times
# The top 35 all seed investor is Social Leverage occuring 44 times

# %% [markdown]
# ## University of founders

# %%
temp = df_All_Companies_merged['universities_of_founders'].values[:].tolist()
list_all_universities_of_founders_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]
list_all_universities_of_founders_unfiltered = reduce(lambda x,y :x+y ,list_all_universities_of_founders_unfiltered)
list_all_universities_of_founders = list(set(list_all_universities_of_founders_unfiltered))
list_all_universities_of_founders_and_count = [[0,x] for x in list_all_universities_of_founders]

for x in list_all_universities_of_founders_unfiltered:
    idx = list_all_universities_of_founders.index(x)
    list_all_universities_of_founders_and_count[idx][0] += 1

list_all_universities_of_founders_and_count.sort(reverse=True)

for idx, value in enumerate(list_all_universities_of_founders_and_count):
    if idx == 10: break
    print('The top {} all university of founder is {} occuring {} times'.format(idx + 1, value[1], value[0] ))
# Out:
# The top 1 all university of founder is Stanford University occuring 1421 times
# The top 2 all university of founder is Massachusetts Institute of Technology occuring 795 times
# The top 3 all university of founder is University of California Berkeley occuring 698 times
# The top 4 all university of founder is University of California occuring 589 times
# The top 5 all university of founder is Harvard University occuring 481 times
# The top 6 all university of founder is Harvard Business School occuring 399 times
# The top 7 all university of founder is Carnegie Mellon University occuring 356 times
# The top 8 all university of founder is University of Pennsylvania occuring 350 times
# The top 9 all university of founder is Cornell University occuring 316 times
# The top 10 all university of founder is Wharton School of the University of Pennsylvania occuring 305 times

# %% [markdown]
# ## Degree of founders

# %%
temp = df_Successful_merged['degrees_of_founders'].values[:].tolist()
list_all_degrees_of_founders_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]
list_all_degrees_of_founders_unfiltered = reduce(lambda x,y :x+y ,list_all_degrees_of_founders_unfiltered)
list_all_degrees_of_founders = list(set(list_all_degrees_of_founders_unfiltered))
list_all_degrees_of_founders_and_count = [[0,x] for x in list_all_degrees_of_founders]

for x in list_all_degrees_of_founders_unfiltered:
    idx = list_all_degrees_of_founders.index(x)
    list_all_degrees_of_founders_and_count[idx][0] += 1

list_all_degrees_of_founders_and_count.sort(reverse=True)

for idx, value in enumerate(list_all_degrees_of_founders_and_count):
    if idx == 10: break
    print('The top {} all degree of founder is {} occuring {} times'.format(idx + 1, value[1], value[0] ))
# Out:
# The top 1 all degree of founder is BS occuring 765 times
# The top 2 all degree of founder is BA occuring 514 times
# The top 3 all degree of founder is MBA occuring 477 times
# The top 4 all degree of founder is unknown occuring 332 times
# The top 5 all degree of founder is MS occuring 325 times
# The top 6 all degree of founder is B.S. occuring 208 times
# The top 7 all degree of founder is B.A. occuring 144 times
# The top 8 all degree of founder is PhD occuring 128 times
# The top 9 all degree of founder is B.S occuring 104 times
# The top 10 all degree of founder is BBA occuring 67 times

# %% [markdown]
# ## Subject_degrees_of_founders

# %%
temp = df_Successful_merged['subject_degrees_of_founders'].values[:].tolist()
list_all_subject_degrees_of_founders_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]
list_all_subject_degrees_of_founders_unfiltered = reduce(lambda x,y :x+y ,list_all_subject_degrees_of_founders_unfiltered)
list_all_subject_degrees_of_founders = list(set(list_all_subject_degrees_of_founders_unfiltered))
list_all_subject_degrees_of_founders_and_count = [[0,x] for x in list_all_subject_degrees_of_founders]

for x in list_all_subject_degrees_of_founders_unfiltered:
    idx = list_all_subject_degrees_of_founders.index(x)
    list_all_subject_degrees_of_founders_and_count[idx][0] += 1

list_all_subject_degrees_of_founders_and_count.sort(reverse=True)

for idx, value in enumerate(list_all_subject_degrees_of_founders_and_count):
    if idx == 15: break
    print('The top {} all degree of founder is {} occuring {} times'.format(idx + 1, value[1], value[0] ))
# Out:
# The top 1 all degree of founder is Computer Science occuring 732 times
# The top 2 all degree of founder is unknown occuring 582 times
# The top 3 all degree of founder is Economics occuring 203 times
# The top 4 all degree of founder is Electrical Engineering occuring 165 times
# The top 5 all degree of founder is Finance occuring 104 times
# The top 6 all degree of founder is Mechanical Engineering occuring 99 times
# The top 7 all degree of founder is Computer Engineering occuring 90 times
# The top 8 all degree of founder is Business Administration occuring 61 times
# The top 9 all degree of founder is Business occuring 59 times
# The top 10 all degree of founder is Physics occuring 55 times
# The top 11 all degree of founder is Mathematics occuring 55 times
# The top 12 all degree of founder is Entrepreneurship occuring 45 times
# The top 13 all degree of founder is  Economics occuring 41 times
# The top 14 all degree of founder is Political Science occuring 39 times
# The top 15 all degree of founder is Electrical Engineering and Computer Science occuring 39 times

# %% [markdown]
# ## prev_companies_of_founders

# %%
temp = df_Successful_merged['prev_companies_of_founders'].values[:].tolist()
list_all_prev_companies_of_founders_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]
list_all_prev_companies_of_founders_unfiltered = reduce(lambda x,y :x+y ,list_all_prev_companies_of_founders_unfiltered)
list_all_prev_companies_of_founders = list(set(list_all_prev_companies_of_founders_unfiltered))
list_all_prev_companies_of_founders_and_count = [[0,x] for x in list_all_prev_companies_of_founders]

for x in list_all_prev_companies_of_founders_unfiltered:
    idx = list_all_prev_companies_of_founders.index(x)
    list_all_prev_companies_of_founders_and_count[idx][0] += 1

list_all_prev_companies_of_founders_and_count.sort(reverse=True)

for idx, value in enumerate(list_all_prev_companies_of_founders_and_count):
    if idx == 15: break
    print('The top {} previous company is {} occuring {} times'.format(idx + 1, value[1], value[0] ))
# Out:
# The top 1 previous company is Google occuring 220 times
# The top 2 previous company is Microsoft occuring 114 times
# The top 3 previous company is Meta occuring 87 times
# The top 4 previous company is Yahoo occuring 73 times
# The top 5 previous company is  Inc. occuring 73 times
# The top 6 previous company is Apple occuring 47 times
# The top 7 previous company is Branch occuring 45 times
# The top 8 previous company is Twitter occuring 43 times
# The top 9 previous company is Stanford University occuring 42 times
# The top 10 previous company is Goldman Sachs occuring 41 times
# The top 11 previous company is Cisco occuring 40 times
# The top 12 previous company is IBM occuring 38 times
# The top 13 previous company is Techstars occuring 36 times
# The top 14 previous company is McKinsey & Company occuring 36 times
# The top 15 previous company is Amazon occuring 35 times

# %% [markdown]
# ## Prev_title_of_founders

# %%
temp = df_Successful_merged['prev_title_of_founders'].values[:].tolist()
list_all_prev_title_of_founders_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]
list_all_prev_title_of_founders_unfiltered = reduce(lambda x,y :x+y ,list_all_prev_title_of_founders_unfiltered)
list_all_prev_title_of_founders = list(set(list_all_prev_title_of_founders_unfiltered))
list_all_prev_title_of_founders_and_count = [[0,x] for x in list_all_prev_title_of_founders]

for x in list_all_prev_title_of_founders_unfiltered:
    idx = list_all_prev_title_of_founders.index(x)
    list_all_prev_title_of_founders_and_count[idx][0] += 1

list_all_prev_title_of_founders_and_count.sort(reverse=True)

for idx, value in enumerate(list_all_prev_title_of_founders_and_count):
    if idx == 15: break
    print('The top {} previous title of founders is {} occuring {} times'.format(idx + 1, value[1], value[0] ))
# Out:
# The top 1 previous title of founders is Co-Founder occuring 1843 times
# The top 2 previous title of founders is Founder occuring 1098 times
# The top 3 previous title of founders is Advisor occuring 968 times
# The top 4 previous title of founders is Founder & CEO occuring 698 times
# The top 5 previous title of founders is Co-Founder & CEO occuring 572 times
# The top 6 previous title of founders is Board Member occuring 572 times
# The top 7 previous title of founders is Co-founder occuring 470 times
# The top 8 previous title of founders is CEO occuring 339 times
# The top 9 previous title of founders is Co-Founder and CEO occuring 314 times
# The top 10 previous title of founders is Co-Founder & CTO occuring 312 times
# The top 11 previous title of founders is Team Member occuring 272 times
# The top 12 previous title of founders is Founder and CEO occuring 271 times
# The top 13 previous title of founders is Investor occuring 267 times
# The top 14 previous title of founders is Software Engineer occuring 243 times
# The top 15 previous title of founders is  CEO occuring 215 times

# %% [markdown]
# # University rankings augmentation

# %%
'''

This section is compose of three sections. 

First we look at the list of all the universities that the founders have attended and we will see look up the
ranking of that university. To begin,

list_all_universities_of_founders_rankings is a 2d list. The structure of each list in this list of lists are
[University name, University rank, university score]

The university names fields is taken from the data set of companies

Now we do sevarl matchin process to see if we have a rank for this university

1. See if founder university is in ranking table
2. Check if founder university is in ranking table when remove the key words 
'','university', 'University', 'university of', 'University of', 'University Of'
3. Use difflib.get_close_matches to get close matches of the University of the founders
4. Lastly, We see if the university on our ranking table is in the founders university list
if soo, the we assume we have a correct match

If a univeristy was not found then it was assigned a minimum rank of 1300
and a minimum score of 20

'''

default_value = -1
minumum_overall_score = 20
minumum_rank = 1300
list_all_universities_of_founders_rankings = [[x, default_value,default_value] for x in list_all_universities_of_founders]

#Most Accurate Matching
for idx1 in range(len(list_all_universities_of_founders)):
    for idx2 in range(len(df_University_Rankings['Institution_Name'].values[:])):
        if list_all_universities_of_founders[idx1] in df_University_Rankings['Institution_Name'].values[idx2]:
            list_all_universities_of_founders_rankings[idx1][1] = df_University_Rankings.at[idx2, 'RANK_2022']
            list_all_universities_of_founders_rankings[idx1][2] = df_University_Rankings.at[idx2, 'Overall']
         

removal_strings = ['','university', 'University', 'university of', 'University of', 'University Of']

for name in removal_strings:
    for idx1 in range(len(df_University_Rankings['Institution_Name'].values[:])):
        for idx2 in range(len(list_all_universities_of_founders)):        
            if df_University_Rankings['Institution_Name'].values[idx1].replace(name,'').strip() in list_all_universities_of_founders[idx2] and list_all_universities_of_founders_rankings[idx2][1] != default_value:
                list_all_universities_of_founders_rankings[idx2][1] = df_University_Rankings.at[idx1, 'RANK_2022']
                list_all_universities_of_founders_rankings[idx2][2] = df_University_Rankings.at[idx1, 'Overall']

for idx1 in range(len(list_all_universities_of_founders)):
    temp = difflib.get_close_matches(list_all_universities_of_founders[idx1],df_University_Rankings['Institution_Name'].values[:])
    if temp and list_all_universities_of_founders_rankings[idx2][1] != default_value:
        list_all_universities_of_founders_rankings[idx1][1] = df_University_Rankings.loc[df_University_Rankings['Institution_Name'] == temp[0], 'RANK_2022'].values[0]
        list_all_universities_of_founders_rankings[idx1][2] = df_University_Rankings.loc[df_University_Rankings['Institution_Name'] == temp[0], 'Overall'].values[0]

for name in removal_strings:
    for idx1 in range(len(df_University_Rankings['Institution_Name'].values[:])):
        temp = difflib.get_close_matches(df_University_Rankings['Institution_Name'].values[idx1].replace(name,'').strip(),list_all_universities_of_founders)
        for elem in temp: 
            idx2 = list_all_universities_of_founders.index(elem)
            if list_all_universities_of_founders_rankings[idx2][1] != default_value:
                list_all_universities_of_founders_rankings[idx1][1] = df_University_Rankings.at[idx1, 'RANK_2022']
                list_all_universities_of_founders_rankings[idx1][2] = df_University_Rankings.at[idx1, 'Overall']

for x in list_all_universities_of_founders_rankings:
    if x[1] == -1: 
        x[1] = minumum_rank
        x[2] = minumum_overall_score

# %%
'''#University ranking Aggregation


We assign a rank and score to the university of all of the founders
We save the best, worse and average rank and score of the universities of the founders

'''

temp = df_All_Companies_merged['universities_of_founders'].values[:]

df_All_Companies_merged['universities_of_founders_rankings'] = float('nan')
df_All_Companies_merged['universities_of_founders_rankings']  = df_All_Companies_merged['universities_of_founders_rankings'] .astype(object)
df_All_Companies_merged['best_ranking_universities_of_founders'] = float('nan')
df_All_Companies_merged['worse_ranking_university_of_founders'] = float('nan')
df_All_Companies_merged['average_ranking_university_of_founders'] = float('nan')
df_All_Companies_merged['percentage_of_founders_attended_university'] = float('nan')

df_All_Companies_merged['universities_of_founders_scores'] = float('nan')
df_All_Companies_merged['universities_of_founders_scores']  = df_All_Companies_merged['universities_of_founders_scores'] .astype(object)

df_All_Companies_merged['best_score_universities_of_founders'] = float('nan')
df_All_Companies_merged['worse_score_university_of_founders'] = float('nan')
df_All_Companies_merged['average_score_university_of_founders'] = float('nan')


for idx in range(len(temp)):
    if not isinstance(temp[idx], str):
        if math.isnan(temp[idx]):
            continue
    temp_university_names = temp[idx].split(',')
    number_of_universities = len(temp_university_names)
    temp_university_rankings = []
    temp_university_scores = []
    
    for university_name in temp_university_names:
        idx2 = list_all_universities_of_founders.index(university_name)
        temp_university_rankings.append(list_all_universities_of_founders_rankings[idx2][1])
        temp_university_scores.append(list_all_universities_of_founders_rankings[idx2][2])
    
    df_All_Companies_merged.at[idx, 'universities_of_founders_rankings'] = ','.join([str(elem) for elem in temp_university_rankings])
    df_All_Companies_merged.at[idx, 'best_ranking_universities_of_founders'] = np.min(np.array(temp_university_rankings))
    df_All_Companies_merged.at[idx, 'worse_ranking_university_of_founders'] = np.max(np.array(temp_university_rankings))
    df_All_Companies_merged.at[idx, 'average_ranking_university_of_founders'] = np.average(np.array(temp_university_rankings))
    
    df_All_Companies_merged.at[idx, 'percentage_of_founders_attended_university'] = number_of_universities / df_All_Companies_merged.at[idx, 'number_of_founders']
    
    df_All_Companies_merged.at[idx, 'universities_of_founders_scores'] = ','.join([str(elem) for elem in temp_university_scores])
    df_All_Companies_merged.at[idx, 'best_score_universities_of_founders'] = np.max(np.array(temp_university_scores))
    df_All_Companies_merged.at[idx, 'worse_score_university_of_founders'] = np.min(np.array(temp_university_scores))
    df_All_Companies_merged.at[idx, 'average_score_university_of_founders'] = np.average(np.array(temp_university_scores))
    

'''df_All_Companies_merged[['universities_of_founders_rankings','best_ranking_universities_of_founders',
                         'worse_ranking_university_of_founders','average_ranking_university_of_founders',
                         'percentage_of_founders_attended_university','universities_of_founders_scores',
                         'best_score_universities_of_founders','worse_score_university_of_founders',
                         'average_score_university_of_founders']]'''
print()

# %%
'''
The data set 'degrees of founders (unedited).xlsx' was labeled by hand.

It was created by all of the degrees that the founders obtained and we normalised it to be either a Doctorate degree or
above, masters, bachelors, associates, highschool or unknown. We assume all founders have completed highschool

Once we have normalised the diversity of dergree title to one of these few categories we then assign a value to each one 
Doctorate is 4
Masters is 2
Bachelors is 1
Associate is 0.5
others are 0

These numbers are absolutely arbitrary. 


One we have standardised the degrees of the founders, we the compute the best degree, worse degree, average degree score
'''

df_highest_education_map = pd.read_excel (r'Data/degrees of founders (unedited).xlsx')
df_highest_education_map.drop(index = [0], inplace=True)
standardised_degree_list = ['Doctorate', 'Masters', 'Unknown', 'Associate', 'Bachelors', 'DroppedOut', 'HS']
standardised_degree_list_and_values = [['Doctorate', 4],
                                       ['Masters',2],
                                       ['Unknown', 0],
                                       ['Associate', 0.5],
                                       ['Bachelors', 1],
                                       ['DroppedOut', 0],
                                       ['HS', 0]]

#Average Education Ranking

temp = df_All_Companies_merged['degrees_of_founders'].values[:].tolist()

df_All_Companies_merged['degrees_of_founders_standardised'] = float('nan')
df_All_Companies_merged['degrees_of_founders_standardised']  = df_All_Companies_merged['degrees_of_founders_standardised'] .astype(object)
df_All_Companies_merged['degrees_of_founders_standardised_numbers'] = float('nan')
df_All_Companies_merged['degrees_of_founders_standardised_numbers']  = df_All_Companies_merged['degrees_of_founders_standardised_numbers'] .astype(object)
df_All_Companies_merged['best_degree_of_founders'] = float('nan')
df_All_Companies_merged['worse_degree_of_founders'] = float('nan')
df_All_Companies_merged['average_degree_of_founders'] = float('nan')
df_All_Companies_merged['percentage_of_founders_with_a_degree'] = float('nan')

exceptional_degree_names = ['','N/A','NA']

for idx in range(len(temp)):
    if not isinstance(temp[idx], str):
        if math.isnan(temp[idx]):
            continue
    temp_degree_names = temp[idx].split(',')
    number_of_degrees = len(temp_degree_names)
    temp_degree_standardised = []
    temp_degree_standardised_score = []
    for degree_name in temp_degree_names:
        if degree_name in exceptional_degree_names:
            temporary = 'Unknown'
        else:
            temporary = df_highest_education_map.loc[df_highest_education_map['degrees'] == degree_name, 'degrees_standardised'].values[0]
        idx2 = standardised_degree_list.index(temporary)
        temp_degree_standardised.append(standardised_degree_list_and_values[idx2][0])
        temp_degree_standardised_score.append(standardised_degree_list_and_values[idx2][1])
    
    df_All_Companies_merged.at[idx, 'degrees_of_founders_standardised'] = ','.join([str(elem) for elem in temp_degree_standardised])
    df_All_Companies_merged.at[idx, 'degrees_of_founders_standardised_numbers'] = ','.join([str(elem) for elem in temp_degree_standardised_score])
    df_All_Companies_merged.at[idx, 'best_degree_of_founders'] = np.min(np.array(temp_degree_standardised_score))
    df_All_Companies_merged.at[idx, 'worse_degree_of_founders'] = np.max(np.array(temp_degree_standardised_score))
    df_All_Companies_merged.at[idx, 'average_degree_of_founders'] = np.average(np.array(temp_degree_standardised_score))
    
    df_All_Companies_merged.at[idx, 'percentage_of_founders_with_a_degree'] = number_of_degrees / df_All_Companies_merged.at[idx, 'number_of_founders']
    
'''df_All_Companies_merged[['degrees_of_founders_standardised','degrees_of_founders_standardised_numbers',
                         'best_degree_of_founders','worse_degree_of_founders',
                         'average_degree_of_founders','percentage_of_founders_with_a_degree']]'''
print()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [65], in <cell line: 46>()
#      56     temporary = 'Unknown'
#      57 else:
# ---> 58     temporary = df_highest_education_map.loc[df_highest_education_map['degrees'] == degree_name, 'degrees_standardised'].values[0]
#      59 idx2 = standardised_degree_list.index(temporary)
#      60 temp_degree_standardised.append(standardised_degree_list_and_values[idx2][0])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
boundaries = [10, 20, 25, 50, 100, 250, 500, 2000]
bar_plot_data = [len(df_All_Companies_merged['average_ranking_university_of_founders'][(np.isnan(df_All_Companies_merged['average_ranking_university_of_founders']) == False) & (df_All_Companies_merged['average_ranking_university_of_founders'] <= rank) & (df_All_Companies_merged['success_flag'] == 1)])/ len(df_All_Companies_merged['average_ranking_university_of_founders'][(np.isnan(df_All_Companies_merged['average_ranking_university_of_founders']) == False) & (df_All_Companies_merged['average_ranking_university_of_founders'] <= rank)]) for rank in boundaries]
print(bar_plot_data)

ind = np.arange(len(boundaries))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('Max University Ranking')
plt.title('TREND OF SUCCESS BASED ON AVERAGE RANKING OF UNIVERSITY BY MEMBERS ON THE TEAM')
plt.xticks(ind, boundaries)
plt.savefig(r'Figures\average_ranking_university_of_founders_success_trend.png')
plt.show()
# Out:
# [0.2962962962962963, 0.29041095890410956, 0.2914438502673797, 0.2938775510204082, 0.2822695035460993, 0.2697866483138334, 0.26744868035190617, 0.24147958590205887]

# %%
boundaries = [10, 20, 25, 50, 100, 250, 500, 2000]
bar_plot_data_1 = [len(df_All_Companies_merged['best_ranking_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders']) == False) & (df_All_Companies_merged['best_ranking_universities_of_founders'] <= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries]
bar_plot_data_2 = [len(df_All_Companies_merged['best_ranking_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders']) == False) & (df_All_Companies_merged['best_ranking_universities_of_founders'] <= rank)]) for rank in boundaries]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('University Ranking')
plt.title('TREND OF SUCCESS BASED ON BEST RANKING OF UNIVERSITY BY MEMBERS ON THE TEAM')
plt.xticks(ind, boundaries)
plt.savefig(r'Figures\best_ranking_universities_of_founders_success_trend.png')
plt.show()
# Out:
# [1245, 1477, 1512, 1997, 2481, 3708, 5500, 8597]

# %%
names = [x[1] for x in list_all_category_groups_list_and_count[:20]]
bar_plot_data_1 = [0 for x in list_all_category_groups_list_and_count[:20]] 
bar_plot_data_2 = [0 for x in list_all_category_groups_list_and_count[:20]]

temp = df_All_Companies_merged['category_groups_list'].values[:]
list_all_category_groups_list_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]

for idx in range(len(temp)):
    if not isinstance(temp[idx], str):
        if math.isnan(temp[idx]):
            continue
    for idx2 in range(len(names)):
        if names[idx2] in temp[idx]:
            bar_plot_data_2[idx2] += 1
            if df_All_Companies_merged.at[idx, 'success_flag'] == 1:
                bar_plot_data_1[idx2] += 1

ind = np.arange(len(names))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, np.array(bar_plot_data_1) / np.array(bar_plot_data_2), width,alpha=0.7,)
 
plt.ylabel('Probability')
plt.title('TREND OF SUCCESS AS BASED ON CATEGORY GROUP (TOP 20)')
plt.xticks(ind, names)
plt.xticks(rotation=90)
plt.savefig(r'Figures\category_group_success_trend.png')
plt.show()

# %%
names = [x[1] for x in list_all_category_list_and_count[:20]]
bar_plot_data_1 = [0 for x in list_all_category_list_and_count[:20]]
bar_plot_data_2 = [0 for x in list_all_category_list_and_count[:20]]

temp = df_All_Companies_merged['category_list'].values[:]
list_all_category_list_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]

for idx in range(len(temp)):
    if not isinstance(temp[idx], str):
        if math.isnan(temp[idx]):
            continue
    for idx2 in range(len(names)):
        if names[idx2] in temp[idx]:
            bar_plot_data_2[idx2] += 1
            if df_All_Companies_merged.at[idx, 'success_flag'] == 1:
                bar_plot_data_1[idx2] += 1

ind = np.arange(len(names))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, np.array(bar_plot_data_1) / np.array(bar_plot_data_2), width,alpha=0.7,)
 
plt.ylabel('Probability')
plt.title('TREND OF SUCCESS AS BASED ON CATEGORY (TOP 20)')
plt.xticks(ind, names)
plt.xticks(rotation=90)
plt.savefig(r'Figures\category_success_trend.png')
 
plt.show()

# %%
names = [x[1] for x in list_all_prev_companies_of_founders_and_count[1:20]]
bar_plot_data_1 = [0 for x in list_all_prev_companies_of_founders_and_count[1:20]]
bar_plot_data_2 = [0 for x in list_all_prev_companies_of_founders_and_count[1:20]]

temp = df_All_Companies_merged['prev_companies_of_founders'].values[:]
list_all_prev_companies_of_founders_unfiltered = [x.split(',') for x in temp if isinstance(x, str)]

for idx in range(len(temp)):
    if not isinstance(temp[idx], str):
        if math.isnan(temp[idx]):
            continue
    for idx2 in range(len(names)):
        if names[idx2] in str(temp[idx]):
            bar_plot_data_2[idx2] += 1
            if df_All_Companies_merged.at[idx, 'success_flag'] == 1:
                bar_plot_data_1[idx2] += 1

ind = np.arange(len(names))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, np.array(bar_plot_data_1) / np.array(bar_plot_data_2), width,alpha=0.7,)
 
plt.ylabel('Probability')
plt.title('TREND OF SUCCESS AS BASED ON PREVIOUS COMPANY FOUNDERS WORKED AT (TOP 20)')
plt.xticks(ind, names)
plt.xticks(rotation=90)
plt.savefig(r'Figures\previous_company_success_trend.png')
plt.show()

# %% [markdown]
# # Grouping of Data
# All of the previous analysis shows us some signals that increase the success of a company. Using these signals, we shall now aggregate the data in the following way to reduce it's dimension for better training.
#
# 1. We shall group people where atleast one of the founders that went to top 10, top 25, top 50, and rest usiversities together and give them the flags 3,2,1,0 respectively
#
# 2. We shall also have a flag if a team went to a top 10 univerisity or not. This will be denoted by a 1 or 0.
#
# 3. WE SHALL REPEAT STEP 1 AND 2 WITH NUMBER OF INVERTORS AND THE SUCCESS RATE OF THE INVESTORS

# %%
best_ranking_universities_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['best_ranking_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)] , [25, 50, 75]))
best_ranking_universities_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['best_ranking_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)] , [25, 50, 75]))
df_All_Companies_merged['best_ranking_universities_of_founders_grouping_scaling'] = float('nan')

boundaries = [0, 
              best_ranking_universities_of_founders_success_quantiles[0], 
              best_ranking_universities_of_founders_success_quantiles[1], 
              best_ranking_universities_of_founders_unsuccessful_quantiles[1],
              2000]
grouping_scale = [3,2,1,0]
for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['best_ranking_universities_of_founders'] <= boundaries[idx + 1]) & ( df_All_Companies_merged['best_ranking_universities_of_founders'] > boundaries[idx]) ,'best_ranking_universities_of_founders_grouping_scaling'] = grouping_scale[idx]

    
corr_params = ['best_ranking_universities_of_founders_grouping_scaling','best_ranking_universities_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2)))

bar_plot_data_1 = [len(df_All_Companies_merged['best_ranking_universities_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['best_ranking_universities_of_founders'] <= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['best_ranking_universities_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['best_ranking_universities_of_founders'] <= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('University Ranking')
plt.title('TREND OF SUCCESS BASED ON BEST RANKING OF UNIVERSITY BY MEMBERS ON THE TEAM GROUPED')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\best_ranking_universities_of_founders_grouping_scaling.png')
plt.show()
# Out:
# The correlation between Success and best_ranking_universities_of_founders_grouping_scaling: 0.05438222794617243
# The correlation between Success and best_ranking_universities_of_founders: -0.06269130447618688
# [1950, 4112, 4512, 8597]

# %%
#Binary grouping based on best quantile of of success
best_ranking_universities_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['best_ranking_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)] , [25, 50, 75]))
best_ranking_universities_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['best_ranking_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)] , [25, 50, 75]))

df_All_Companies_merged['best_ranking_universities_of_founders_binary_grouping_scaling'] = float('nan')

boundaries = [0, 
              best_ranking_universities_of_founders_success_quantiles[0],
              2000]
grouping_scale = [1,0]

for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['best_ranking_universities_of_founders'] <= boundaries[idx + 1]) & ( df_All_Companies_merged['best_ranking_universities_of_founders'] > boundaries[idx]) ,'best_ranking_universities_of_founders_binary_grouping_scaling'] = grouping_scale[idx]


corr_params = ['best_ranking_universities_of_founders_binary_grouping_scaling','best_ranking_universities_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2)))
    
bar_plot_data_1 = [len(df_All_Companies_merged['best_ranking_universities_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['best_ranking_universities_of_founders'] <= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['best_ranking_universities_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['best_ranking_universities_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['best_ranking_universities_of_founders'] <= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('University Ranking')
plt.title('TREND OF SUCCESS BASED ON BEST RANKING OF UNIVERSITY BY MEMBERS ON THE TEAM GROUPED')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\best_ranking_universities_of_founders_binary_grouping_scaling.png')
plt.show()
# Out:
# The correlation between Success and best_ranking_universities_of_founders_binary_grouping_scaling: 0.04680265125546171
# The correlation between Success and best_ranking_universities_of_founders: -0.06269130447618688
# [1950, 8597]

# %%
#Number of founders grouping
number_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['number_of_founders'][(np.isnan(df_All_Companies_merged['number_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)], [0, 25, 50, 75, 100]))
number_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['number_of_founders'][(np.isnan(df_All_Companies_merged['number_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)], [0, 25, 50, 75, 100]))
df_All_Companies_merged['number_of_founders_grouping_scaling'] = float('nan')

boundaries = [number_of_founders_success_quantiles[4] + 1, 
              number_of_founders_success_quantiles[3], 
              number_of_founders_success_quantiles[2], 
              number_of_founders_unsuccessful_quantiles[2],
              0]
grouping_scale = [3,2,1,0]
for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['number_of_founders'] >= boundaries[idx + 1]) & ( df_All_Companies_merged['number_of_founders'] < boundaries[idx]) ,'number_of_founders_grouping_scaling'] = grouping_scale[idx]

    
corr_params = ['number_of_founders_grouping_scaling','number_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2)))  

bar_plot_data_1 = [len(df_All_Companies_merged['number_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['number_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['number_of_founders'] >= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['number_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['number_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['number_of_founders'] >= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('Number of Founders')
plt.title('TREND OF SUCCESS BASED ON NUMBER OF FOUNDERS')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\number_of_founders_grouping_scaling.png')
plt.show()
# Out:
# The correlation between Success and number_of_founders_grouping_scaling: 0.030358394318560772
# The correlation between Success and number_of_founders: 0.028530137493664367
# [3218, 5629, 5629, 8591]

# %%
#Number of founders binary grouping
number_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['number_of_founders'][(np.isnan(df_All_Companies_merged['number_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)], [0, 25, 50, 75, 100]))
number_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['number_of_founders'][(np.isnan(df_All_Companies_merged['number_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)], [0, 25, 50, 75, 100]))
df_All_Companies_merged['number_of_founders_binary_grouping_scaling'] = float('nan')

boundaries = [number_of_founders_success_quantiles[4] + 1, 
              number_of_founders_success_quantiles[3], 
              0]
grouping_scale = [3,2,1,0]
for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['number_of_founders'] >= boundaries[idx + 1]) & ( df_All_Companies_merged['number_of_founders'] < boundaries[idx]) ,'number_of_founders_binary_grouping_scaling'] = grouping_scale[idx]

    
corr_params = ['number_of_founders_binary_grouping_scaling','number_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2)))

bar_plot_data_1 = [len(df_All_Companies_merged['number_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['number_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['number_of_founders'] >= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['number_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['number_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['number_of_founders'] >= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('Number of Founders')
plt.title('TREND OF SUCCESS BASED ON NUMBER OF FOUNDERS')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\number_of_founders_binary_grouping_scaling.png') 
plt.show()
# Out:
# The correlation between Success and number_of_founders_binary_grouping_scaling: 0.03413445124670274
# The correlation between Success and number_of_founders: 0.028530137493664367
# [3218, 8591]

# %%
#Number of previous titles of founders grouping
number_of_prev_title_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['number_of_prev_title_of_founders'][(np.isnan(df_All_Companies_merged['number_of_prev_title_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)], [0, 25, 50, 75, 100]))
number_of_prev_title_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['number_of_prev_title_of_founders'][(np.isnan(df_All_Companies_merged['number_of_prev_title_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)], [0, 25, 50, 75, 100]))
df_All_Companies_merged['number_of_prev_title_of_founders_grouping_scaling'] = float('nan')

boundaries = [number_of_prev_title_of_founders_success_quantiles[4] + 1, 
              number_of_prev_title_of_founders_success_quantiles[3], 
              number_of_prev_title_of_founders_success_quantiles[2], 
              number_of_prev_title_of_founders_unsuccessful_quantiles[2],
              0]
grouping_scale = [3,2,1,0]
for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['number_of_prev_title_of_founders'] >= boundaries[idx + 1]) & ( df_All_Companies_merged['number_of_prev_title_of_founders'] < boundaries[idx]) ,'number_of_prev_title_of_founders_grouping_scaling'] = grouping_scale[idx]

    
corr_params = ['number_of_prev_title_of_founders_grouping_scaling','number_of_prev_title_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2))) 

bar_plot_data_1 = [len(df_All_Companies_merged['number_of_prev_title_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['number_of_prev_title_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['number_of_prev_title_of_founders'] >= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['number_of_prev_title_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['number_of_prev_title_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['number_of_prev_title_of_founders'] >= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('Experience of Founding Team')
plt.title('TREND OF SUCCESS BASED ON NUMBER OF PREVIOUS TITLES HELD BY FOUNDERS')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\number_of_prev_title_of_founders_grouping_scaling.png') 
plt.show()
# Out:
# The correlation between Success and number_of_prev_title_of_founders_grouping_scaling: 0.06921441645036798
# The correlation between Success and number_of_prev_title_of_founders: 0.05201187359625507
# [2704, 5771, 6728, 12083]

# %%
'''
The goal of this section is to infer a level of experience from the team. We count the number of previous
position held by the founding team, the number of those which have been managerial or greater. 

We also average against the number of founders

'''

df_all_prev_title_of_founders = pd.read_excel (r'Data/prev_title_of_founders (edited).xlsx')
df_All_Companies_merged.at[idx, 'number_of_founders']

temp = df_All_Companies_merged['prev_title_of_founders'].values[:].tolist()

df_All_Companies_merged['prev_title_of_founders_managerial_flag_collated'] = float('nan')
df_All_Companies_merged['prev_title_of_founders_managerial_flag_collated']  = df_All_Companies_merged['prev_title_of_founders_managerial_flag_collated'] .astype(object)
df_All_Companies_merged['number_of_prev_title_of_founders'] = float('nan')
df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'] = float('nan')
df_All_Companies_merged['number_of_prev_title_of_founders_per_founder'] = float('nan')
df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_per_founder'] = float('nan')


exceptional_prev_title_names = ['','N/A','NA', 'n/a']

for idx in range(len(temp)):
    if not isinstance(temp[idx], str):
        if math.isnan(temp[idx]):
            continue
    temp_prev_title_names = temp[idx].split(',')
    temp_prev_title_names = [x for x in temp_prev_title_names if not(x in exceptional_prev_title_names)]
    #print(temp_prev_title_names)
    
    number_of_prev_title_of_founders = len(temp_prev_title_names)
    temp_prev_title_of_founders_managerial_flag_collated = []
    
    for prev_title_names in temp_prev_title_names:
        
        try:
            temporary = df_all_prev_title_of_founders.loc[df_all_prev_title_of_founders['prev_title_of_founders'] == prev_title_names, 'prev_title_of_founders_flag'].values[0]
        except:
            print(prev_title_names)
            
        temp_prev_title_of_founders_managerial_flag_collated.append(temporary)
    
    df_All_Companies_merged.at[idx, 'prev_title_of_founders_managerial_flag_collated'] = ','.join([str(elem) for elem in temp_prev_title_of_founders_managerial_flag_collated])
    df_All_Companies_merged.at[idx, 'number_of_prev_title_of_founders'] = len([x for x in temp_prev_title_of_founders_managerial_flag_collated if x != -1])
    df_All_Companies_merged.at[idx, 'managerial_flag_number_of_prev_title_of_founders'] = len([x for x in temp_prev_title_of_founders_managerial_flag_collated if x == 1])
    df_All_Companies_merged.at[idx, 'number_of_prev_title_of_founders_per_founder'] = len([x for x in temp_prev_title_of_founders_managerial_flag_collated if x != -1]) / df_All_Companies_merged.at[idx, 'number_of_founders']
    df_All_Companies_merged.at[idx, 'managerial_flag_number_of_prev_title_of_founders_per_founder'] = len([x for x in temp_prev_title_of_founders_managerial_flag_collated if x == 1]) / df_All_Companies_merged.at[idx, 'number_of_founders']
    
'''df_All_Companies_merged[['prev_title_of_founders','prev_title_of_founders_managerial_flag_collated','number_of_prev_title_of_founders',
                         'managerial_flag_number_of_prev_title_of_founders','number_of_prev_title_of_founders_per_founder',
                         'managerial_flag_number_of_prev_title_of_founders_per_founder']]'''
print()
# Out:
# Marketing Manager LATAM
# Senior Engineer Manager
# General Manager / Senior Director
# Sr. Manager Business Development & Product Management
#  Consumer Products
# General Manager / Senior Director
# Sr. Manager Business Development & Product Management
#  Consumer Products
# Software Engineer & Product Management
# R&D Engineer/Project Manager
# Vice President of Platform & Advertising
# Business Development & Growth
# Business Development & Growth
#  Business Development (via Acompli)
# Frontend Design/Engineering Lead
# Software Engineer – Google+
# Director of Business Development - East Coast
# EVP of Business Development & Marketing
# Director of Marketing Technology
# Founder & Head of Growth
# Performance Marketing Associate Manager
# Co-founder & Technical Advisor
# Head of Enterprise Technology
#  Member Technology
# Sales Development Representative and Co-Founder
# Senior Software Developer and Co-Founder
#  Emerging Solutions
#  Information Quality Products
# Strategic Advisory Board
#  Tools Product Marketing
# Equities Technology Summer Analyst
# Research Assistant at Technology and Innovation Lab
# Science and Quantitative Reasoning Tutor
# Software Development Engineering Intern
#  CTO and COO
# Corporate and Securities Lawyer
# Corporate and Securities Lawyer
# Founder & Chief Brand Officer
#  Misinformation
#  and Trust
#  Misinformation
#  and Trust
# Innovation Fund Chair
# Co-Founder and Chief Imaginator
# Prosperity Mortgage Division
# Senior Advisor - Federal Housing Administration
# Senior Operations Manager
# Single Family Execution Strategies
# Wholesale Lending
# Co-Founder and Chief Imaginator
# Prosperity Mortgage Division
# Senior Advisor - Federal Housing Administration
# Senior Operations Manager
# Single Family Execution Strategies
# Wholesale Lending
# Co-Founder/ Director
# C-President
# CPO & Co-President
# Product Team Lead
#  Business Internet Services Division
# Investor/board member
#  GP
#  Business Devlopment
# Vice President Operations - Western Region
# Sr. Manager - Catalog & Data Product
# Product Designer and User Experience Developer
# Cofounder & Head of Hardware
# Senior Director and Chief of Staff to CEO
# Investor Growth
# Head Of International
# Head of Marketing and Growth
# Specialist + Lead Concierge
#  Enterprise Search
# iVP sales
# Co-FOunder and CEO
# Co-Founder & Head of Product Design
#  Google Analytics
# Audit Intern
# CFO/ CRO
# Co-Founder - Vice President of Growth and Experience
# Director of Site Development
#  Acquisition Marketing
# Investor and Chief Product Officer
#  Web Operations
# Product Management and Marketing Strategy
# Product/UX Strategist
# Recruiter
#  Office Manager
# Senior Vice President of Revenue
# VP User Experience
# Vice President - Product
# Vice President of Merchandising
# National lead coach
#  USA Intl Math Olymp Team
# Co-Founder and Science Director
# Patterson Rockwood Professor of Energy and Professor of Chemistry
#  Senseable City Lab
# SVP of Business Development and General Counsel
# Business Development Team
#  Community Team
#  & Social Media Marketing Coordinator
# Consumer Marketing
# Marketing Administrator
# Corporate Consulting
#  Eastern Sales
# EVP Security & Surveillance Solutions
#  Front-End Engineering
# head of product
#  Corporate Brand Development
# Business Unit Co-Founder
# Founder and Senior Vice President of Emerging Business
#  New England
# Co-founder and Chief Customer Officer
# Research Assistant and Phd Student
# Summer Undergraduate Researcher
# Chief Investment Officer & Co-Founder
# Futures - Control & Trade Management Group
# Senior Member Technical Staff
# Senior Consultant/Team Leader - Commonwealth Bank of Australia
# Solution Architect/Team Leader
# Marketplace Partner Advisory Group
#  Consumer Advsiory Board
# Co-Founder/Growth
# Teachable
# Head of Partnerships and Investing
# Head of Strategy and Investing
# Vice-President of Business Development
# Co-founder & Chief Scientific Officer
# Laboratory Operations Manager
# Scientific Founder
# Scientific Founder
# Player Experience Lead & Co-Founder
#  Director of Research and Partnerships
# Head Page
# Managing Director and VP
#  New Markets
# Sr Architect
# Former Team Leader
# Past Employee
# Senior Finance Advisor
#  Atlas
# Special Operations - Diving Officer
# Editor At Large (following Mic acquisition) and Adviser
# Editor-at-Large & Co-Founder
# Venture Partner Network
# Co-Founder and Chief Security Officer
# Vice President Products
# Technical Lead - SPARC Central Solenoid & Poloidal Field Coils
# Co-Founder & Chief Euphorics Officer
# Sr. Director and Global Head of Engagement
# Vice President - Equity Derivatives
# Senior Director of Cloud & AI - Microsoft for Startups
# Visiting Scholar Scientist
# Board Member and Senior Advisor
# Co-founder | Operations | Product Manager
# Consultant for Spanish Startup: Social ERP Telegestion
# Head of IT
# VP Strategic Services
# Advisor and Independent Board Member
#  Founder and Designer
# Frontend engineer
# EVP Strategy and Special Projects
# Member of the Corporate Sponsorship Program
# VP of P&C
# Fellow of the School of Engineering
# Global Director of Digital Product
# Ecommerce Consultant
# Senior Application Engineer
# Global Head of Health & Wellness
# Product Development Consultant
# Product Development Consultant
#  Global Delivery Operations & Strategy
# Co-Founder & Managing Director APAC
# Co-Founder & Chief Community Officer
# Co-General Manager of BarkEats
# Membership and Strategy
# Sales and Operations Manager
# Sales and Operations Manager
# Biology Research Assistant
# Physics and Engineering Researcher
#  now investors
# Limited Investor
# Limited Investor
# Limited Investor
# Limited Investor
# Co-Founder & Operations Executive
# Sales and Business Development
# Sr. Partner Sales Executive
# Strategic Partner Manager
# Head of Communications & Partnerships
# Head of Communications & Partnerships
# Co Founder / VP Engineering
# Producer / Owner
# Director and Portfolio Manager
# Financial Engineering Intern
# Quantitative Research Associate
# Director of Marketing & Growth
# Head of Global Demand Gen (tibbr)
# VP of Production
#  Smart Ads
#  Dapper
#  Dapper
# MTV News & Docs
# National Infrastructure Advisory Council
# Private Wealth Advisor
#  CHAIRMAN
#  PRESIDENT OF M&A AND STRATEGIC PARTNERSHIPS
# Founder and Managing Editor
#  Co-CEO and Creative Director
# IT Student Analyst
# Software Engineer / Consultant
# Senior Engineer Lead
#  Jungle Scout
# Fundraising Associate
# Implementation Team
# Implementation Team
# Chief Data Scientist and Cofounder
# VP of Product & Innovation
# Co-Founder/ Director
# Co-Founder & Organizer
# Head of Front-end Engineering
# Co-Founder / Head of Design
# City Director - Melbourne
# City Director - Melbourne
# Lead Electrical & Product Development Engineer
# Lead Electrical and Product Development Engineer
# Scout Investor
# Software and Flight Controls Engineer
#  GNC
#  Engineering Contractor
# CTO and CO-Founder
# CTO and CO-Founder
# Ambassador of Buzz at Grasshopper
# Founder CEO & President
# Algorithms Specialist / R&D Manager
# CTO / CPO
# Co - founder & COO
# Co Founder & Business Advisor
# Co Founder & CTPO
# Co-Founder and CTO/CPO
# R&D Department Manager
# Search Engine Marketing Analyst
# Search Engine Marketing Manager
# Conference Advisor
# Conference Chair
# Director of Flight Operations
# Spacecraft Engineer
#  Lead for Mechanical and Electrical Engineering Teams
# Alumni Representative
# Founder and Marketing Executive (CMO)
# Designer and Co-Founder
# Manager and Product Management
# Designer and Co-Founder
# Manager and Product Management
# Designer and Co-Founder
# Manager and Product Management
# Designer and Co-Founder
# Manager and Product Management
# Trauma Surgeon
# ​CEO
#  CEO and investor
# Vice President - Equity Derivatives
# Co-Founder & Director of Mechanical Engineering
# Food Waste Activist
# Co-Founder and Head of EPD
#  President & Chief Business Officer
#  President & Head Of CRE
#  Head Of Resident Services & Partnerships
# Marketing Project Manager
# Ruby and iOS Consultant
# Senior Design Verification and Simulation Engineer
# Senior Verification Engineer
#  Deal team
# Founding Technical Partner
# Senior Staff Tech Lead Manager
# Tech Lead Manager
# Hackerrr
# Head of Core Product
#  Activation
#  Editor-in-Chief
#  TechTicker—Yahoo! Finance
#  Columnist
#  Investment Professional
# Advisor: Graphite Team
# Cause Hacker
#  Cause Hacker
# Dir. of Engineering - Developer Platform
#  Jim of all trades
# Co-founder and Chief Operating Officer
# Angel Philanthropist
# Co-Founder & Technical Advisor
# Recruiting Manager
# Co-Founder and Design
# Co-Founder and Design
# Founding Associate
#  Strategy & Corporate Development (Digital Finance)
# Business Intelligence and Strategy Manager
# Strategic Finance
#  Artificial Intelligence Lab
# Professor of Computer Science and Neural Science
# VP & Chief AI Scientist
#  Chief Product Officer & Founder
# E4 Specialist
# Executive Relationship Manager
# Executive Relationship Manager
# People Manager
# People Manager
# Technology and Infrastructure Advisor
#  Healthy for Life Community Solutions Team
# Head - Sales & Co-Founder
#  Yahoo! Mobile
# Head of Community & Growth
# Senior Vice President Of Global Sales
#  GM & Vice President
# VP of Enginering & Co-Founder
# Vice President of Product & Platform
# Entrepeneur-in-Residence
# Organizer/Founder
# Director of Operations Strategy
# Global Head of New Business Development
# Options Market Making
# Advisor to Female-Founded Stanford Startup
# Advisor to Female-Founded Stanford Startup in Cannabis Industry
# Finance Director & Company Secretary
#  Chairperson & Board of Directors
# Government Business Development Executive
# Member of StartX Med COVID-19 Task Force
#  Hadoop
# VP Big Data Analytics
# Senior UX Researcher and Designer
#  Chairperson
# Chief Medical & Technology Officer & Co-founder
# Chief Scientific Officer & Co-founder
# Business Advisory Services Associate
# Finance Manager
# General Manager & VP
# New Ventures Lead
# Sr. Manager Amazon Last Mile - DSP Business Coaches - California
#  New Business Group; Sr Director
#  Search Marketing & Category Management
# Founding team
# Online Producer
#  Global Digital Initiatives
# Product Team
# Product Mgmt
#  Business Dev Intern
# Co-founder + VP of Engineering
# Staff Product Manager - Recommendations
# Co-Founder and Head of Product & Design
# Founding team member
#  Atlanta
# Video Specialist
#  Private Shares Group
# Sr. Director of Software Engineering (Planning/Delivery/Controls/Robotics/Enterprise/ML)
# VP of Product Management & Clinical Apps
# Associate Buyer- Macy's West
# Co-Founder/Chief Merchandising Officer
# Director Merchandising
#  GM of West (SF and AZ)
#  Head of Technology and Architecture
# Biomedical Design Engineer
# Product Design Engineer
# Supply Base Engineer
# Chief Experience Officer & Co-Founder
# Co-Founder/CRO
# Co-founder & Lead Front-end Developer
#  Sales and Revenue
# Performance Consultant
# Petroleum Engineer
# Chief Innovation Officer & CTO
# Co-Founder and Head of Clinical Services
# Co-founder & Creative Direction
# Global Digital Creative Director
# Partner & Head of Product
# Co-Founder -- SVP of University Partnerships
# Founder & Past President
# Past President
# Superintendent
# Head of Strategy & Operations
# Co-Founder/President & COO
# University of Hamburg
# Creative Director - Super Chewer
# Technology Investor
# Founder & Chief Clinical Officer
# Technology Advisory Board
# Technology Advisory Board
#  Brand & Marketing Lead
# Co-Founder / Board Director
#  Financial Services
# Founding Team / Director of Corporate Development
# Investor & Co-founder
# Investor / Board Director
# Investor / Co-founder
# Principal / Venture Partner
#  Marketing and Analytics
# Data Insights Engineer
# President and Chief Revenue Officer
# Co-founder / President
# President's Leadership Council
# Vice President Strategy Business Development
# Dir/VP Marketing
# Marketing and Systems Engineering
# Advisor & Seed Investor
# Advisory Board & Investor
# Head of Strategy and M&A
# Series A Investor
#  Wag.com
# VP of Brand Marketing
# Co-founder (Product + Engineering)
# Machine Learning Infrastructure Engineer
# Co-Founder and Adviser
# Co-founder / Creative Director
# Healthcare Investment Banking
# Participant Founder
# Participant Founder
# CEO AOL Israel
#  IL GM & CTO
# Sr. Vulnerability Research Engineer
# Founder and Chairperson
# Co-Founder & VP Strategic Development
#  Facebook Reality Labs Social Experiences
# President & Corporate EVP
# Propulsion Lead Analyst
#  Segment Leadership Groups
# Co-Founder & Director of Hardware Engineering
# Co-Founder & Director of Software Engineering
# Co-CTO and Co-Founder
# Technical Product Director
# TitleFounder and Chairman of the Board
# TitleFounder and Chairman of the Board
# iOS team
# Founder & Head of Community
# ANTS Project Lead Designer
# DB Rethinker
# Mechanical Systems Designer
# Retail
# Co-Founder | Head of Customer Experience
# Co-Founder & Former CEO
# Founding Designer
# Ex-Head of Product
# Founder and Ex-CEO
# please see linkedIn profile for a full list
# Co-founder & Principal Engineer
# Digital & Mobile Media
# Product + Design Cofounder
# Computer Vision Research
# Robotics Researcher
# Sales Ops PM
# Entrepreneur and Founder
# Nitro Advisor
# Lead Program Manager - MSN Music
# Lead Program Manager - Xbox Live
# Product Leadership
# VP General Manager
# Loss Prevention Officer
# Product Marketing Lead
#  SuperApp & Ventures
# SVP of Product Strategy
# Business Risk & Economics Consultant
# CEO/Board Member
# CEO/Board Member
# DSP Design Engineer
# DSP Design Engineer
# Fulfillment Optimization SDE
# Fulfillment Optimization SDE
# Director of Online Marketing
# Manager - Marketing Planning & Analysis
# Tech Lead & Manager
# CEo
# Vice President Business Development & Distribution
# Vice President of Business Development and Co-Founder
# Director
#  Connected Life
# Director of Engineering & Founder
# Co-Founder & CEO Asia
# Co-Founder & CEO Asia
#  CEO Asia
#  CEO Asia
# Graduate Finance Summer Intern
# Co-Founder & VP of Software Development
# Cofounder - CTO
#  Financial & Market Intelligence
#  myRA
# Founder and Zoo Director
# Project Assistant - President's Office
# Strategy Consultant - Automotive
# Founder & Chief Inspirer - Band Member
# VP Platform & Co-founder
# VP Platform & Co-founder
# VP Platform Performance & Co-founder
# VP Platform Performance & Co-founder
# Co-founder - Machine Learning
# Development Branch Chief
# Director Of Research & Co-Founder
# Director of Computer Vision
# Marketing & Engineering
# Marketing and Engineering
# Co-Founder & Backend Team Leader
# Co-Founder & Head of Technology
# Beijing Office - Health & Nutrition Program - Volunteer
# MBA Intern
#  Top Seller Development
# Product / Design / Community
# Course Peer Tutor
# SWE intern
# Co-founder & Frontend Tech Lead
# Early stage Investor
# Front End Developer
#  Yahoo! Real Estate
# Futures Broker
# Institutional equity/derivatives trader
# Interim Head of Design
# Interim Head of Design
#  Andela Advisory Council
# Life Member
# Technical Pre-Sales & Product Management
# Technical Pre-Sales & Product Management
# Technical Pre-Sales & Product Management
# Principal Engineer/Architect
# Principal Engineer/Architect
# Vice President - Sales Business Development
# Advisor | Investment Analyst
#  Invoices
# Head of Customer Development and Co-Founder
# Equities Trader
# Team Lead Software Engineering
# Analyst & Operations
# Business Process Analyst
# Community Program Manager
#  Meltano
# Head of Search & Discovery
#  Google Play
# Programming and Research Intern
# Software Developing Engineer Intern
# CEO / Technical Co-Founder
# Head of Clinical Product
# Product Lead at Uber Eats
# Startup School Advisor
# Strategy & BizOps Lead
# CoFounder and VP Production
# Co-Founder & Head Hustler
# Strategic Growth
# Application Engineer
# Lead Frontend Engineer & iOS Ninja
# Principal & Strategy
# Senior Strategy Lead
#  Connected Car Digital Ventures
# Founder & Director of Operations
# iOS Developer & Engineering Intern Program Lead
#  Publishing & Investing (Contract)
# Co-Founder + EVP
# Co-Founder + Head of Product
# Head of Growth Product
# Head of Growth Product
# Co-founder and VP of Robotics
# Author & The Book of Esports
# Hospitality Lead
# Scholar of Esports (Professor)
#  Non-Traditional Development
# Senior Global Brand Manager
# Strategy and Integration Team Intern
# Sr. Software Egineer
# Concept Creative
# Interactive Creative
# Imagineer
# Co-Founder & Head of Software Engineering
#  Design & Front-End Development
#  VP of Sales & Marketing
# Founder / Head of Strategy
#  NYC
#  Culture
#  and Hiring.
# CEO advisor
# Investor and Investment Committee Member
#  Enterprise Software
#  Mobile Sales
# Exec Chairman
# Member of Board of Investers
# Co-Founder &President
# Digital Marketing Specialist
# Engineer (Hololens)
# Customer Success
# Bioinformatician
# Owner/Executive Vice President
#  Sales and Service
# Principal/Co-Founder
# Chief Operating Officer & Co-founder
# YouTube Business Development & Partnerships
# Associate Professor of Radiology
#  Brain Team
#  Brain Team
# CTO at Apella Technology
#  SMSS
# Co-Founder & Chief Technical Oliver
# iPhone & iPad
#  Salesforce Marketing Cloud
# Co-Founder & Technical Advisor
# Co-Founder and Head of Strategy and Culture
#  Head of Solutions and Strategy
# Group Program Manager
#  CPO and Senior Software Engineer
# Product & Design Lead
# VP and Head of Engineering
# Software Design Engineer Intern
# Co-Founder and Board Chairman
#  Acting CBO
#  Acting CEO
#  and Acting CBO
# Director of Molecular Surgical Laboratory
#  Research & Chief Scientific Officer
# Founding CEO and Board Member
#  Drug Discovery
# Professor of Surgery
#  Microbiology and Immunobiology
# SVP / Chief Scientific Officer
#  Drug Discovery
# Scientific Founder
#  Partnerships & BD
# Member Of The Board Of Advisor
#  Sales and Marketing and Executive Vice President
#  New Business Initiatives
# Transportation Partnerships
# Director of Business Operations
# Advisor--Technology
# Co-Founder & Chief Analytics Officer
# Credit Risk Analytics
#  Senior Advisor
# Head Of Analytics
# Head of Analytics and Marketing
# Led the Development Team
#  and Marketing Analytics
# Founding Investor & Board Member
#  Driver
#  Uber For Business
# Founder & Senior Engineer
# CTO/CIO
#  General Manager of R&D
# VP Architecture
# Actuarial Intern
# Principal Software Engineering Lead
# CEO at Rakuten Loyalty
#  Executive Officer at Rakuten
# Chief Innovation Officer & Co-founder
# Co-Founder and Head of Operations
# Co-Founder and Vice President of Platform Engineering
#  Head of Finance
#  Head of Finance
#  Head of Global Strategic Partnerships
#  Head of Global Strategic Partnerships
#  BD & Ventures
# Co - founder & COO
# Advisory Committee
# EIR (Entrepreneur In Residence)
#  Communications and Brand Engagement
# Co Founder & Spain Country Manager
# Compliance Officer
# Flash Developer
# Product Manager (Daydream
#  Virtual Reality)
# Partner/ Founder and COO
#  Trips & Search
#  contractor
# web developer
# CBO & Co-founder
# VP of Business Developmet
# CBO & Co-founder
# VP of Business Developmet
# Board Member & Adbvisor
# CTO/CIO
# CTO/CIO
# Chief Revenue Office
#  UI/UX - Digital Presence
#  UI/UX - Digital Presence
# Founder and VP of Business Development
#  Chief Design Officer
#  Chief Design Officer
#  VP of Product and Design
#  VP of Product and Design
#  VP of Creative
#  VP of Creative
#  Digital Presence
#  Global Product Operations and Integration
# VP of Product and Design
# VP of Product and Design
#  Product and Growth
#  Product and Growth
#  Digital Presence
# Co-Founder & Chief Policy Officer
# Researcher - Applied Physics and Electrical Engineering
# Aalyst
# Innovation Strategy & Business Development
#  Industrial Products
#  WeWork Labs
# Vice President of SW Engineering
# R&D Chief
#  Services & Integrations
#  Creative Cloud Experience & Engagement
# Stanford Student Space Initiative
# Co-founder and Chief Scientific Advisor
# General Manager Online Advertising
# General Manager Online Advertising
# Head of Product Engineering
#  HRIS & Platform
# Managing Director Digital Strategy & Partnerships (AdAdvisor)
# Managing Director Digital Strategy & Partnerships (AdAdvisor)
# Sr. Director of Software Development
# Chief Operating Officer & Head of Business
# Co-founder & Chief Merchandising Officer
# Director of Content & Community
# Lecturer in Management
#  Center for Entrepreneurial Studies
# Co-Founder & Co-Chairperson of the Board
# Founder & Co-Chairperson of the Board
# Head of Audiobooks and Gated Content
#  Aviary
# Head of Talk (Podcasts
#  and Live)
#  Aviary Team
#  Board Member & Co-Founder
#  Board Member & Co-Founder
# Corporate Audit Staff
# Director of Industrial Engineering + OPS
# Director of Industrial Engineering + OPS
#  Global Engineering
# Black Rock Ranger
# Director of Data Product
# Director of IT Operations
# Product Manager & Data Scientist
#  Content Understanding & Search
# Senior Data Product Manager
#  Home Feed Ranking & Blending
# Channel Partner Manager - WhatsApp Partnerships
# Co-Founder - CFO
#  CTO & CIO
# Co-founder / Head of Business Development
# Senior Publisher Account Manager Europe
# Coding Mentor
#  Head of Sales & Partnerships
# coding mentor
# Head of Communications and Recruiting
# Reporter and Editor
# Marketing Manager & Founder
#  Business Internet Services Division
# Head of Presentation Experience & Special Projects
# Investor/board member
#  GP
#  Business Devlopment
# VP - Legal & Deputy General Counsel
# VIce President & Global Head of Platforms
# Senior Tech Lead
# Sr. Development Manager
# Technology Consultant & Software Engineer
# VP Engineering & Operations
# Business Development / Product Manager - Summer Internship
#  Global Head of Software Central Engineering and Key Project Manager
# Financial Planning Manager
# GM/PEM
# SVP / GM
#  Sales Product Division
#  Sales Product Division
# Side project
#  VP Tech
# Head of Coinbase Cloud
#  Financial Media
# Founder / Executive Director
# Head of Risk Management and Analytics
# Runway Entrepreneur
# Head of Artificial Intelligence & Machine Learning
# Co-founder & Product Lead
# Co-Founder & Executive of Product
# Co-Founder & Tax Attorney
# CTO and Co founder
# Chief Travel Officer and Founding Member
# Bridgewater Associates Senior Software Developer Lead
# CTO and Technical Cofounder
# Senior Systems Engineer - Market Data Technology Manager
# Co-founder & Head
# EVP Product & Engineering
# UI Designer/Engineer at The Washington Post
#  Platform & Growth
# VP of Digital Product
# Corporate and Business Development
# Vice President/Debt Investor
# GM GarageGames.com
# Production Engineering Manager
# Combustion Pressure Sensor Designer
# PhD Candidate Researcher
# Radiologist in Chief
# About.com Investment Club Guide
# Director product
# ID-Cloud TC Member
# Payments Product Lead
# Strategic Advisor / DTC expert
# Trust and Safety
#  and Cofounder
# Entrepreneur in Residence (EIR)
# Director Development Operations
#  Rupture
# System Architecture Consultant
#  Express
#  Worldwide Marketing & Product
# Head of Channel Sales
# Architect/Engineer
# Information Technologies Specialist
# Java Engineer
# Project Coordinator/Java Engineer
# Advisor and Strategy Consultant
#  Head of Science
#  Coaching and Programs
# Health Educator and Behavior Coach
#  Stanford Children's Hospital
# Lead Behavior Coach
#  Kurbo
# Doctoral Fellow
# IR Science Advisor
# Search/Relevance Tech Lead
# Senior Computer Scientist
# Software Eng.
# Visiting Distinguished Scientist
# CEO and Vice President of Engineering
# Fonder
# Chemistry Ph.D.
# Principal PM
# Executive Women in Product Lead and Chair
#  P&M
# Ph.D Research
# Ph.D Voigt Lab.
#  Voigt Lab
# Cloud CTO
# Co-Founder & Chief Security Officer
# Computer Network Exploitation Analyst/Technical Lead
# President / CEO (Co-Founder)
#  Facility Security Officer
# Senior Malware and Forensics Analyst
# Co-Founder and Chair of Scientific Advisory Board
# Head of Molecular Biology
#  CPO & Co-Founder
# Visisting Scholar
#  Chair
# Head of Microbiome
# Board of Directors & Executive Producer
# Tools Architect
# Engineering Management and Product
# Mentor & Angel investor
#  architect
#  School of Medicine
#  Professor of Medicine
#  of Genetics
#  of Biomedical Data Science
# CTO & President
#  Chief Operating Office
# Co-Founder / Chief Hacker
#  Chief Architect & Lead Developer
# GM Data Partnerships
#  CTO & CSO
# S17 Alumni
# Co-Founder & Head of Product
# Developer Ecosystem
#  Heroku and Heavybit
#  Chief Technology Officer & Founder
# Staff Manager
# Cardiologist
# Co-Founder & Chief Medical Advisor
#  Scripps Research
#  Scripps Research Translational Institute
# Key Founding Advisor
#  Metacafe Israel
# Sr. Director Product Management
#  Technology & Operations
# Chief Scientist (Acquired by Microsoft)
# Co-founder and CTO (Acquired by Rocket Lawyer)
#  Senior Adviser
# Senior Product Manager - Digital Health
# Senior Vice President - Strategy
# Director of Biotech Ventures
# Fonder
# Industry Transformation Officer
# Mental Health Lead Advisor
#  Chief Strategy Officer & Chairman
# Co-founder & Atmospheric Science Team Lead
#  SoundBlaster
#  Executive Vice-President Strategic Ventures and Business Development
#  Product and Operations
# FOUNDER FELLOWSHIP (ODF9)
# FOUNDER | Chief Executive Officer
# Founder Fellow
# Founder Fellow
# Founder Fellow (ODF10)
# Founder and Executive Chairperson
# Founders Fellow
# Growth Warmer
# Head of Recruiting and Co-Founder
# North America Ecosystem Lead - Open Innovation
# On Deck Founder Fellowship
# Strategic Partner Manager
# VP Brand & Innovation Strategy
#  Enterprise & Strategy
# Startup Architect
# Advisor — AI Index
# Board of Advisors on Computer Science
# Externship (via ATLAS Institute)
# Venture Partner (AI Fund)
#  Audience Development & Content Operations
# Brand Partner
# Director of Trade and Environment
#  Investments and New Business
# Fund Development
# Special Assistant to Undersecretary
#  Member of Board
# Chief Data
#  and Fraud Officer
#  Trust & Safety
#  Trust & Safety
#  Head of Business
# Growth & Digital Marketing Manager
#  Ecosystem Relations
#  Ads Quality Operations
# Lead Project Engineer
#  Product Quality Operations
#  Search Quality
# VP Risk Strategy
# Consumer
# Former General Partner
# Sr Infrastructure Developer
# Associate Professor of Databases
# Co-founder & Head of Operations
# Backup Operations (Bank of America Acct.)
# VP Engineering & Chief Technology Officer
# Co-Founder & Creative Technologist
# Chief Architect/Co-Founder
# Head - Engineering & IT
#  Merchandise Strategy and Supply Chain
#  Merchandise Strategy and Supply Chain
# Global Head of Innovation
# Head of Supply Chain
# Head of Supply Chain
# Apttus Labs
#  India Operations
#  Head of Influence
# Global Digital Brand Director
# Investor / Creative Advisor
# Vice President of Customer Support
#  COO & Director
# VP Customer Success Operations
# CTO / Growth & Strategy Partner
# Growth & Strategy Lead / Managing Director
# Speaker/Panelist
# Co-Founder and Customer Development
# CFO / VP of Product Management
# Co - Founder & Board Director
# Chief of Innovative Applications
# Co-Founder & VP of Strategic Projects
#  Starlink Network
#  Starlink Network
# Program Manager for Advanced Projects
# Head of BD
# Anagram
# Mission Caretaker and Founder
# CEOa and Founder
# Product Partner
# Health
# Co-Founder & CINO
# Venture Capital Associate @ Fundersclub
# CS106 Section Leader
# CodeDay San Francisco Organizer
# Founders Program Fellow
# Genomics Research Intern
# VP Product and Design
#  Home Page and Navigation
# Entrepreneurial Fellow
# Performance Marketing
# Director of Technology & Product Development
# Sr Analyst
# Sr Platform Engineer
# Technology Analyst Intern
# Co-Founder & Head of Product & Growth
# Professor of Economics
#  Chief Marketing Officer and Chief Product Officer
#  Cofounder & Board of Directors
# Chief Scientist and Co-Founder
# Founder and Senior Advisor
# NextGen
#  Board Advisor
#  Board Advisor
# CEO Octopus Energy USA
# Director of Growth and Marketing
# Director of Sales – Americas
# GP
# CTOCTO Thirty Madison
# VP Infrastructure
# VP Infrastructure
# Entrepeneur-in-Residence
# NCAA Athlete Tutor
#  COO & Head of Network Operations
# Original Lead Developer
# CTO / DPO
# Co-Founder and Head of Marketing (acquired by Ooma Inc)
# Head of SEO
# Founding Co-Chairman
# CEO& co-founder
# SVP Strategic Partnerships
# Sr Director of Product
#  Data and Growth Products
# Co-Founder and Head of Operations
# Co-founder & SVP of Product
#  Skills
# Co-Founder & Head of Strategy
# Director of Biomedical Informatics at the Genomics and Pathology Services
# Director of Biomedical Informatics at the Genomics and Pathology Services
# Director of Center for Biomedical Informatics
# Director of Center for Biomedical Informatics
#  Chief Technology & Innovation Officer
#  Chief Technology & Innovation Officer
# President of Marketing
# Techstars Graduate
# VP Global Sales
# VP of Brand Partnerships
# VP of Global Sales / Co-Founder
# BD Intern
# Partner & Chief Operating Officer
# VP General Manager of Rapid Intake
# Head of Membership and VP of Product
# CEO.
# Chairman + Co Founder
# Co-Founder + Board Member
# Head of BD & Strategy
# Co-Founder and Director of Engineering
#  Head of Product & Marketing
# Product Marketer
# Stratagic Planner
# Chief Brand Officer and Co-Founder
# Head of Regional Operations
# something new
# Cofounder/VP of Engineering
# SVP and GM
# SVP and GM
# Maker
# Lead Electrical & Product Development Engineer
# Lead Electrical and Product Development Engineer
# Scout Investor
# Software and Flight Controls Engineer
#  GNC
#  Engineering Contractor
# LinkedIn Intro
# Engineer - Advanced Engineering
# Investment Banking Summer Associate - Technology
# Partner - Venture Capital
# VP of Product & Engineering
# Chief Financial Officer & Chief Strategy Officer
# Chief Financial Officer & Chief Strategy Officer
# Director of Marketing Partnerships
# Director of SPG Loyalty Program
# Sr. Director Sales Strategy & Operations
# VP Product - Customer Experience & Innovation
# Co-Founder and Adviser
# Healthcare Investment Banking
# Participant Founder
# Research Analyst Intern
# Director Product Management & Technical Services
# Product & Tech Services
# Product and Ops
# Technical Pre-Sales & Product Management
# CoFounder & CoCEO
# Head of Services
# Head of Coinbase Cloud
# Avdisor
# Executive Vice President and GM
#  Home and Kitchen
# Global Creative Director
# Global Head of Buyer Engagement & Growth
# Marketing Consultant/Ad Salesperson
# Principal & Creative Director
# Product Council Member
# Studio Proprietor & Blogger
#  Buyer Experience & eBay for Charity
# Head of Partner Innovation and VP
#  Business Development & Legal Affairs
# VP Growth & GM
#  EVP Product/CMO
#  VP Professional Services
# Board Member - Colorado
# Co-founder / CPO
# Co-founder / SVP
#  Engineeering
#  Business Markets
# Head of Channel Development
#  Wholesale and Channel Sales
#  LearnVest
# CEO and Co-Founder at Cleancult
# Co-Founder and CTO at Cleancult
# Co-Founder & Chief of Design
# Composite Structural Designer
# Intern to Chief Executive Officer
# Cofounder / Chief Engineer
#  Core Technologies
# Founding Team / Head of Communications
#  Content & Partnerships
# Assistant Professor of Computer Science & Engineering
# Associate Professor of Computer Science & Engineering
# IBM Director
#  MIT-IBM Watson AI Lab
#  IBM Research
# US Investments
# Senior Product Consultant
# Director of Corporate Strategy and Development
# Vice President of Finance and Operations
# Professor of Law & Public Policy
# Senior Advisor for Policy and Technology
# Director of Global Android Partnership
# Entrepreneur-in-Residence/Senior Advisor
# Head of Android Partnership
# Head of Global Device Partnership
# Director of Global Android Partnership
# Entrepreneur-in-Residence/Senior Advisor
# Head of Android Partnership
# Head of Global Device Partnership
# Co-Founder / Head of Platform
# Fundraising and Strategy Advisor
#  Leveraged Finance
# Co-Founder and Chief Product Architect
# Co-Founder and Chief Product Architect
# Cofounder and Chief Technology Officer
# Engineer / iOS Developer
#  Leveraged Finance
# Co-Founder and Chief Product Architect
# Co-Founder and Chief Product Architect
# Cofounder and Chief Technology Officer
# Engineer / iOS Developer
# Head of IT Operations
# Operations Engineer
# Prototype Engineer
# Co-founder & Chief Process Officer
# GPM Mobile Payments
# Senior Product & Program Manager
# led the data infrastructure
# Interim Chief Operating Officer (Consultant)
# Founder/Board Member
# Founder/Board Member
# Founder/Board Member
# Founder/Board Member
#  Apps
# Director of Urban Design and Digital Integration
#  Sidewalk Urban Development
# Software Engineer and Founder
# Co-founder & CSO
# Senior Vice President & Chief Operating Officer
# Technical Lead - Tilt Open
# Chief Executive Office & Co-Founder
# President and Chief Risk Officer
# Co-Founder/CSO
# Bloomberg Chair in Business Journalism for the Graduate School of Journalism
# Co-Founding Editor
# Co-founder and Editor in Chief
#  Signal P&G
# Founding Member of the Board of Directors
#  GP
# Senior Research Scholar and Adjunct Professor
# EVP / CFO
# Co-Founder & Vice President of Product Development
# Product Managment Lead
# Board Member / Hospital Finance Committee
# Founder & Co-Editor
# Member / Mentor
# Board Member Co-Chair
# Co-Founder & CEO / COO
# Co-Founder & Chief International Officer
# Co-founder & Data Expert
# associate
# Co-Founder and Head of Community & People Operations
# VP of Tradesy for Business
# Consulting Proffesor
# Engineering lead of Personalization
# Marketplaces Product Lead
#  Operations Lead
#  Product and Strategy
#  Product and Strategy
# Co-Founder/Engineer
# Co-Founder - Founding CEO
#  AdSense
# Financial Director
# Financial Director
# Co-founder & Chief Talent Officer
# Co-Founder and Co-President
# Intern (Veteran Integration Program)
# Operator-in-residence
#  CTO & Chief Product Officer
# Director of E-Health
# Vice President of Entrepreneurship
# Lead Software Engineer - Mobile
#  Marketplace Platform
# CEO- Founder
# CEO- Founder
# CEO-Founder
# CEO-Founder
# CEO-Owner
# CEO-Owner
# Founder and Advisor to the Board
# Founder and Advisor to the Board
#  Decision Making Team
#  TigerConnect
# Sr. Group Product Manager
#  Emerging Products
# Strategic Alliances Manager
# VP of Retail
# VP of Audio
# Postdoctoral Associate
# Scientific Officer
#  Chief Strategy Officer & Chief Product Officer
#  Chief Strategy Officer & Chief Product Officer
#  Chief Technology Officer and Engineering Manger
#  Chief Technology Officer and Engineering Manger
# Chief Technology Officer & Senior Vice President
# Co-Founder and Board of Director
#  CSO & Head of R&D
# Member of the Board of Directors & Member of the Scientific Advisory Board
# Principal Investigator
# Senior Vice President & CTO
# PhD Physicist
# Co Founder & Head of Product
# Founder & Co-Editor
# Co-Founder and Hacker
# Digital & Mobile Media
# iPhone Developer
# Inheritance Product Lead and Security Researcher
# Machine Learning Intern
# REU Researcher
# Director of Product & Marketing - Head of Search (Paid & Organic)
# Cofounder & Chief Medical Officer
# IOS and Web developer
# Research fellow
# Ruby on Rails developer
# News Anchor
# Political Commentator
#  Sales & Partnerships
#  Chief Business Development and Strategy Officer at Zylo
# Senior Vice-President of Sales
# Vice-President of Sales
# Exec Director of Strategy
# MSTP fellow
# Resident Physician
# Senior Software Engr. (Business Intelligence
#  Analytics)
# Senior Technical
#  Docker Security
# Platform Security Lead
# Chief Digital Strategy Officer
# Managing Director US
# CSO/Co-Founder
# CTO & COO
#  EVP & CRO
# core infrastructure systems
# CEO & Co-Founder @ Done
# Lead Product Manager & Shorts Creation
# Director of Talent
# Group Program Manager
# Advisor & Consultant
#  XIX Digital
# Co-Founder & Advisor (former CRO)
# Cofounder & CSO
#  US Media Sales
# Head of Consumer Marketing
# Interactive Media Supervisor
# Labs Cofounder & CSO
# Resident Scientist
#  Sales & Strategy
#  Development lead
#  and CSO
# Co-Founder & Chairman Of The Board
# Co-Founder and Chief Product and Design Officer
# Development Engineer Embedded Systems
# Graduate Student Instructor
#  Ubiquitous Interaction Group
# Engineering Manager M2/L7
# Investing Partner
# Co-Founder/Head of Engineering
#  US Classifieds & Mobile
# Head of Mobile Strategy and Product Management
# Lead Product Manager - Mobile
#  Voice & Communications Group
# Exec Chairman
# Exec Chairman
# Member of Board of Investers
# Member of Board of Investers
#  Adverse Conditions
# Senior VP of Applications
# Principal Developer on Ksplice Team
# Exec Chairman
# Member of Board of Investers
# SVP Sales & Co-Founder
#  Global Head of Revenue
# Product Manager & Engineer
# CEO & Founder
# Head of Blend
# Head Of Research And Development
# Managing Director Las Vegas
# Software Developer Summer Intern
# Software Developer and API Advocate
# Software Developer and Technical Support
# Undergraduate Research Assistant
# Head of RemoteTeam
# Head of RemoteTeam
# Assistant Professor in Biomedical Sciences
# Assistant Professor in Biomedical Sciences
#  Founder Experience
# Head of Growth and Mobile Emerging Products
# Structured Finance
# co-founder & ceo
# CEO & President @ Yahoo
#  Consumer Web Services
#  Google.com
#  Search Products & User Experience
#  Location & Local Services
# CEO & President @ Yahoo
#  Consumer Web Services
#  Google.com
#  Search Products & User Experience
#  Location & Local Services
# Global Head of Creator Services
# Limited Partner / Adviser
# User Experience Design Intern
# User Experience Design Intern
# User Experience Design Intern
# Chief Product Officer (CPO) & Co-Founder
# Functional Consultant
#  Big Data Tools
# Product Management Technical AI/ML
# Product Management Technical AI/ML
#  COO & CBO
# Investment & Trading Associate
# Exec Chairman
# Head of AI Research
# Head of Data Science and Co-Founder
# Member of Board of Investers
# VP AI Engineering
# Co-Founder & Founding Engineer
# Principal Product Architect
# Co-Founder & Lead Scientist
# SVP Design
# Co-Founder and Strategic Advisor
# Operating Advisor
# Programs Team Lead
# Co-Founder & VP Algorithms
# CorpVP and General Manager of Artificial Intelligence Products Group
# Design & Verfication Engineer
# Design & Verification Engineer
# Design & Verification Engineer
# Part of Qualcomm’s Neuromorphic Research Group
# Postdoctoral Work
# Postdoctoral Work
# Scientific advisory board
# Vice President and General Manager (Intel acquisition)
# Director of Product Management.
# VP of International
# ABS Summer Trading Analyst
#  Logistics
#  and Facilities
# Architectrual Graduate
# President & Co-founder & Product
#  CTO / CPO
# Chief of Staff to the President & Chief Operating Officer
# Founding Member & Board Member
# General Manager & Head of Product- Youth and Student Segments & Chase First Banking
#  Skrill USA
# Co-Founder & Head of Insights
# Co-founder & Chief Growth Officer
# Co-founder & Chief Growth Officer
# Manufacturing Engineer Intern
# Co-CEO and Founder
# CoFounder and Chief Clinical Officer
# Teaching Team
# Co-founder and Board of Advisors
# Co-Founder and Board Advisor
# Summer Co-op
# CEO & President (Founder)
# Research Affiliate and Faculty
# Vice President of Artificial Intelligence
# North America East Coast Leader Microsoft Startups
# Avionics Intern
# Consultant Architect
# Project Zero Intern
# Managing Partner & CTO
# Co-Founder and former Creative Director
# Co-Founder and former President
#  CEO and COO
# Creative Director & Lead the Data Arts Team
# Chief Health Officer & Co-founder
# Chief Health Officer & Co-founder
# Chief Health Officer - Care Lab
# Chief Health Officer - Care Lab
#  Chief Product Officer & VP Strategy
#  Project Lead
#  Care Lab
# Product & Incubation
# Venture
# Principle Product Strategist
# Chief Product Officer/Head of Product
# Director of Strategy and Innovation
# Full-stack Developer
# Chief Scientific Advisor and Founder
# Director of the National Institutes of Health Center of Excellence in Genomic Science
# Director of the U.S. Department of Energy Center on Bioenergy
# Director of the U.S. Department of Energy Center on Bioenergy
# Founder & member of the scientific advisory board
#  SAB Chairman
# Founder/Scientific Advisor
# Member of the Scientific Advisors
# Member of the Scientific Advisors
# Professor of Health Sciences and Technology
# Scientific Strategy Board Member
# Strategic Scientific Advisor
# Co-Founder & Head of User Experience
# Co-Founder & Head of User Experience
#  Security and CISO
# Field Technical Sales Specialist
# Field Technical Sales Specialist
# TitleCo-founder & Head of Product Management
# TitleCo-founder & Head of Product Management
# Vice President of Rentals
# Global Fellow
# General Partner&Co-Founder
# Founder / VP Strategy & Business Development
# VP Software and Founder
# Co-Founder & EVP
# Co-Founder and Executive Vice President of Business Development and Strategy
# Algorithms Group
# Algorithms Group
# Co-Founder & Executive of Product
# Co-Founder & Executive of Product
# Co-Founder & Executive of Revenue
#  Chief Technology Officer & Technology Executive
#  Chief Technology Officer & Technology Executive
# VP Audience & Product Management
# VP Audience & Product Management
# Marketing and Analysis
#  DraftKings N.A. & Co-Founder
#  DraftKings N.A. & Co-Founder
# Co-founder and Executive Chairwoman
# Co-founder and Executive Chairwoman
# Principal Engineer & Co-Founder
# Principle Technology Specialist
# Vice President of Global Sales
#  Web Product Management
# Head of Global Credit Products
#  Global Pay Later Products
# Core Venture Partner
#  Avatar Team
#  Founder & Board Member
# Co-Founder & Head of Business Operations
#  & Business Development
# Interim CMO & Founding Team Member
# Investing
#  Advising
#  & Consulting
# GM EMEA & CISO
# GM EMEA & CISO
# Intern in the systems group at Microsoft Research Cambridge
# Intern in the systems group at Microsoft Research Cambridge
# Founder and Full Stack Developer
#  Goverment IT Project
# Technical Advisory Board member
# CEO- CoinList Digital Asset Services
# Director Security Assurance
# Director of Engineering & Co-Founder
#  Engineering Co-founder
# Engineering co-founder
#  CTO & President
# Assistant Clinical Professor
# Co Founder & Chief Medical Officer
# Co-Founder & VP Engineering Data
# Head of Android Product Marketing
#  APAC
# Mobile Platform Product Marketing
# Architecture Software Team Leader
#  Radio and Music Interactive
# Co-founder & VP Product/Design
# Freelance Data Scientist
#  Yahoo! Brickhouse
#  Ovi Product Development
#  Business Banking at RBC
# Vice President and CIO
# Forbes.com Industry 4.0 Writer
# Project Manager & Tech Director
# Research & Innovation lead
# Co-Founder + Chief Creative Officer
# iTunes Public Relations
# TYE Lecturer
# Clinical Director
#  and Board Director.
# Director of Research & Strategy
# Lecturer : Division of Health Sciences and Technology
# Visiting Researcher Intern
# Co-Founder and VP Sales USA
# Software Engineering Manager / Lead Developer
# CTO & VP Business Development
# Chairman MSMCI USA
#  COO and CFO
# Executive Producer/Co-Founder EA Kids
# Founding VC Investor
# Investor/Board Member
# Senior VP/GM of Turner New Media
# Strategic & Product Management
#  Aviation Development Centers
# Founder and Test & Development Pilot
#  Aviation Development Center
# Photojournalist
# SVP & GM Minerals
# Lead back-end developer
# Technical Co-Founder and CTO
# Founder and Director of Products
# Clinical Assistant Professor
# Radiologist
# Head of Emerging Platforms
#  Data & SaaS
# Director Of Engineering - Vyne Dental + Onederful
# Co-Founder and VP Product
# Co-Founder and VP Product
# Director of Studio Empowerment
# Co-Founder and Vice President of Engineering
#  Angel
# Distribution Partner
# Product and Business Development
# Design / Branding Advisor
# Director Of Marketing
# Head of Content & Camera Marketing
# Sr. Hardware & Systems Engineer
# Street Team Rep
# Vermont Edition News Intern
# Co-Founder & Head of Culinary Operations
# Strategy/CX Advisor
# Chairman USA
#  Yes to Inc.
# Co-Founder & Chief Carrot Lover
# Manufacturing Manager
# Member of the Corporate Board & Corporate Advisory Board
# Guild Member
# Co-founder | CXO
# Enterprise Sales & Blockchain
# Stretch VP Sales
# Applications and Product Engineer
# Applications and Product Engineer
#  FAE
# Founder ans CTO
# Incubator/Non-profit
# Klystron Engineer (Summer Student Intern)
# Lab/Teaching Assistant
# Process Engineering Associate
# R&D/Clinical Intern
# Chief of Workplace Experience & Co-founder
# President and CFO
# Product | Co-Founder
# Co-Founder and Head of Marketing and Growth
# Co-founder and CTO/Inventor
# Co-Founder and VP of Artist Development
# United States Ambassador to the Republic of Austria
# Headmaster and Founder
#  President & Chairman
# Biomedical Engineer Advanced Microsystems
# North American Business Development Manager
#  Sales Strategy & Brand Development
# Chief Resource Officer
# Co-Founder and Chief Systems Architect
# Co-founder / Chief Operating Officer
# Chief Orthodontist and Founder
#  Institutional sales
# Associate - International Capital Group
# RE200 Mentor
# SVP of Finance/Operations
# COFounder
# Founder - Managing Partner
# Founding Angel Investor
# Founding Angel Investor / Boardmember
# Founding angel investor
# Founding angel investor
# NYC Operations
# Valuation Senior Associate
# Vice President of Product Development and Strategy
# Co-Founder and Head of Product & Brand Design
# Purchased Material Quality Engineer
# Purchased Material Quality Engineer
# Co-Founder / Design
#  Operations & Product
#  Web Development Immersive
# NASA Academy Associate
#  Technology and Strategy
#  and CFO
# IdeaHUb Incubator Coordinator
# Director of New Technology
# Chief Scientist and Co-Founder
# Director of Consultant Services
# VP of People Operations
# Chief Napping Officer
# Hacker in residence
#  News
# Application Assessment / Professional Svcs
# Solution Strategy
# Associate - International Capital Group
# Co-Founder & Head of Brokerage
# Leasing Associate
# RE200 Mentor
# Senior Consultant & Head of Sales
# Chief of Patient Access and Head of Commercialization
# Executive Chairman and co-Founder
# Executive Chairman and co-Founder
# President and Director & Founder
# CDS
# Chief Data Scientist & Co-Founder
# Co-founder & Head of Investment Strategy
# Managing Director - Investments & Strategy
# Founder & Warchief of Science
# Co-Founder & President of Operations
# Co-Founder & President of Operations
# Global Advisory Board member
#  international IoT Expo™ conference series
# Venture Partner/Partner
# CEO & Chief Software Architect
# Director of Strategic Initiatives
# Banking & Finance Department
#  VP of Research and Development
# General Manager North America
# Director of Customer Service
# Senior Director of Marketing
# Co-Founder / Head of product and engineering
# Head of marketing and promotions platform
# Creative Consultant
#  Head Of Product
# Digital Media Agent
# Co-Founder & SVP of Finance Operations
# Co-Founder & SVP of Finance Operations
# Sr. Web Technology Architect
# Co-Founder and VP Product
# Growth (Employee #4)
# Data Scientist (Contractor)
# Co-Founder and Head of Growth Engineering
# Head of Strategy & Business Operations
# Software and Sales Engineer
# UI
# Co-Founder & Principal Engagement Engineer
# Co-Founder & Principal Platform Engineer
# Head of User Experience & Design & Co-Founder
# Sr. Manager - Startup Business Development
# CoFounder & CRO
# Project and quality assurance coordinator
# Founding Associate
# MobileVoice & BrandAnswers
# Co-founder + CEO
# VP Strategic Partnerships
# Co-Founder and Director of Engineering
# Chairman @ Madrid Student Branch
# Java developer
# Co-Founder & VP Artist Relations
# Co-Founder & VP Artist Relations
# GVP
#  Security Market
# VP of Global Marketing
# FinOps Lead
# Software Engineer - Data
# Tech Lead - Finance/FinOps Data Engineering
# Service Lead
# Executive Medical Director
# VP Of Business Development and Legal
# Diretor
# Co Founder CTO
# MobileVoice & BrandAnswers
#  Former Co-CEO
# UK Business Development & Project Director
#  Investment
# Agile Engineering Coach
# Senior Director (consultant)
#  Scrum Master
# Board Member and Senior Advisor
# President & COO (Co-Founder)
# President & COO (Co-Founder)
# Lecturer; designed and taught course "Emerging Technologies and Social Impact"
#  Head of ESG
#  Impact and Origination
# Principal of Global Strategic Alliances
# Product Marketing and Product Management
#  Billpoint
# Senior Program Officer
# Partner & Board Member
# Co-Founder - Founding CEO
#  AdSense
# Corporate Banking Relationship Manager & Vice President
# Chief Strategy & Communications Officer
# Co-founder and Clinical Lead
# Co-founder and Data Science Lead
# GM / Group Head of Managed Services & Service Propositions
# Global Head of Knowledge
# SVP / Senior Group Director
#  Head of Corporate Strategy & Business Transformation
#  Chief People and Process Officer
# Director of Business Development & Strategy
# Director of Business Development & Strategy at moovel
#  Future of Transportation
#  VR Platform
# VP Channels and Strategic Partnerships
# Energy Policy and Transportation Policy Analyst
#  R&D and Design
# VP and GM of Practical Guidance & Analytical
#  Application & Sales Engineering
# Co-Founding
# Executive Product Management
# Vice President of Consumer Marketing
# Board & Investor
# CTO and Head of Engineering
#  Engineering Glam Labs
#  Startup Team
#  Instructional Technology
#  National Team
#  Conversation Foundations
#  Conversational Safety
# Tech Lead Manager
#  CTO and CSO
# Engineering & Site Manager
# LATAM CTO
# Board Member and Co-Founder
# Sloan Fellow
# Chief Digital Service Officer
#  Advanced Web Technologies
#  Strategic Engagements
# Head of Engineering for B2B & Platform
# Launch Team
# Senior Software Engineer/Team Lead - Dreamweaver
# Senior Technical Support Specialist
# VP & Product Management
# Managing Director First Republic Bank
# Interim Technology Executive and Agile Coach
# SVP & General Manager
#  Cloud Lending
#  Lead Full-Stack Engineer
# Brand Design Intern
# Co-Founder and Head of Commercial Partnerships
# Head of Incubations Impact
# Head of Mobile Emerging Markets and Proximity Payments
# Sr. Director Product Management
# Brand Design Intern
# Co-Founder and Head of Commercial Partnerships
# Head of Incubations Impact
# Head of Mobile Emerging Markets and Proximity Payments
# Sr. Director Product Management
# ...
# Memphis Chapter Founding Member and Executive Committee Member [currently organizing chapter]
#  Entrepreneurs' Boot Camp
#  Von Allmen Center for Entrepreneurship
# Mentor/Entrepreneur In Residence
# NSF I-Corps Industry Mentor
#  Western Service Region
#  Mallinckrodt/Puritan-Bennett
# SEMDA Medtech Conference Pitch Rounds Co-Chair
# Team Leader/Regional Customer Support Engineer
#  Nellcor Puritan-Bennett
# UCSF Health Hub Advisor - Chief Business Mentor
#  Operations Specialist
#  and Sales/Biz Dev Specialist
# Member Board Of Directors and Co-Founder
# Incubated
#  Center for Entrepreneurial Studies
# Co - Founder / Technologist
#  BookFresh & FreshGuide (Purchased by Sugar Inc.)
# Designer & Founder
# Engineering Development Manager
#  Design Leadership Forum
# UI Strategist
# Founder & Vice President of Biological Sciences
#  Lead Product
# Executive Vice President and Director
# VP of Studio
# C.P.A.
# Vice President Research & Quality Systems
# Consultant in Psychiatry
# Consultant in Psychiatry
# Research Consultant
# Sr. Azure App Innovation Specialist
# Executive Assistant - NFL Player & Marketing Agents
# Ovations
# Global Head of Market Strategy & Planning
#  Channel Marketing
#  Chief Technology Officer and Co-founder
# Co-founder / CPO
# GM and Co Founder
# US Founder & CEO
# Doctoral Fellow
# IR Science Advisor
# Search/Relevance Tech Lead
# Senior Computer Scientist
# Software Eng.
# Visiting Distinguished Scientist
# Enterprise Engineer
# Consulting Search Scientist
# Intel Analyst
# Senior Research Engineer
# Engineering Manager - Galaxy
#  Technical
# Cofounder & Head of Alliances
# Founder and Chief Technologist
#  Enterprise Search
# CEO and Product Lead
#  Co-Founder and Product
# Co-Founder and Brand
# Sr. Manager and Innovation
# Global Account Director
#  Product Management and Amazon Transportation
# Co-founder + CEO
# Co-Founder & President of Advisory Board
#  Pocket
# Financial Software Developer Intern
# US Representative
# Co-Founder & CTO/CPO
# Founder & CBO
#  Operations Lead
# Board Member / Investor
# VP Customer Platforms & Data
#  Director of Research and Partnerships
# Head Page
# Senior Research Scientist - Biomedical Engineering Department
# Co-Founder and Director of Mobile Engineering
# Co-Founder and Engineer
# Business Growth Strategist
# Director Of Client Services
# Director of Digital Marketing and E-commerce
# Director of E-commerce
# Head of Hotel Innovation
# Hotels Program Manager
# Regional Market Manager
# Data Scientist at Center for Data Science and Public Policy
# Physicist and Co-founder
# Enterprise Architect & IT Division Manager
# Managing Director/CEO
# Director of New Technologies
# Director of Product Support
# Senior Level Positions
# Submarine Officer
# Co-Founder and Chief Brand Officer
# Asst. VP and CHIO
# Co-Founder and VP of Research
# Dir. Informatics + Assoc. Professor
# Senior Vice President of Business Development and Point of Care
# Lecturer in Financial Technology
# Head of Coinbase Cloud
# Derivative Transactions
#  Intellectual Property Licensing and Film Finance and Distribution
# Spearheaded Brand Campaign
# Spearheaded Brand Campaign
# Spearheaded Brand Campaign
# Counsel to the Director
#  Bureau of Consumer Protection
# Senior Attorney
#  Division of Privacy & Identity Protection
# Agency Success Manager
# BD & Strategy
# Analyst & Operations
# Business Process Analyst
# Community Program Manager
#  Meltano
#  Health + Medical
#  Health + Medical
# Various Engineering and Management Positions
# Associate Strategy Consultant
# Co-founder/UI Architect
# Global Chief Curator
# Product & Growth (Senior Leadership Team)
# Associate Dean of Biomedical Studies
# Associate Professor & Chair
#  Department of Biology
# Vice President Strategic Marketing
#  Surgical Structural Heart
#  Asia at Edwards Lifesciences
#  Board Executive Advisor
# Lead Software Design Engineer in Test
# VP - Digital Health
#  Head of Digital Health
#  University Development and Legal & Head of Product Management and Business Development
# applications intern
# Alumni Interviewer
# Apparel Advisory Board Member
# CMO & Co-founder
# Data Principal
# Co-founder & VP Of Engineering
# Adjunct Assistant Professor - Dept. of Crop Sciences & Assistant Director
#  Center for Digital Ag
# Director of Agriculture
# Global Head of Carbon
# Director Program Management Office
#  Workforce Management and Strategy - Engagement Services
# Co-Founder & Factotum
# CEO advisor
# Investor and Investment Committee Member
# Head of Sales
#  Zume India and International
# Head of Strategy and Operations
# Head of Growth and Mobile Emerging Products
# Co-Founder VP of Engineering
# Principle Software engineer
# Founder & Co-Head of Engineering
# Founder & Co-Head of Engineering
# Advanced Design Director
#  Producer & President
# Co-Founder and Design Principal
#  Blogger contributor & cool hunter
# Director Growth & Exponential technologies
# VicePresident
# Workload Automation Senior Product Manager
# vGeneral Manager and Advanced Design Director
# Emerging Technology Analyst
# Global Entrepreneurs Council Member
# Honorary Board Member
# Honorary Board Member
# Special Consultant
# Scientific Founder
# Statistician and Programmer
# Co-founder & Technical Advisor
# Director of Information Products
# Director of Information Products
# Institute for Data Sciences and Engineering
# Institute for Data Sciences and Engineering
# Partner/ Founder and COO
#  Trips & Search
#  Thorn Innovation Lab
# Co-Chair of the IAB Native
#  Content & Social Committee
# Head of Global Performance Sales
# Leader on the Client Services and Product Architecture Teams
# Led Custom Engineering Solutions
# Chief Culinary Officer & Co-founder
# Co-Founder & Co-ceo
# Infantry Officer
# Private Wealth Advisor
# Sr. Director of Business Development
# Senior Director of Strategy and Transformation
# EVP of Campus Operations & Education
# Founding Managing Director
#  Endeavor Colorado
# Head of Research & Strategy
# Head of Research and Marketing Sciences
# Quantitative Research Lead
# Senior Manager - Insights & Strategy
# Senior Quantitative Research Manager
#  Site Reliablity
# Co-founder and Chief Customer Officer
# Entrepreneurship Advisory Board
# Entrepreneurship Advisory Board
# Alumni Mentor
#  Coder and Designer
# Chairman USA
#  Yes to Inc.
# Co-Founder & Chief Carrot Lover
# Manufacturing Manager
# Member of the Corporate Board & Corporate Advisory Board
# Co-Founder and Chief Designer
# Head of Platform (Operations)
# Senior Product Designer and Design System Lead
#  & Lead Product Manager (Acquired)
# CTO Farheap Solutions & GM Opensoft
# CTO Farheap Solutions & GM Opensoft
# Chief Medical Officer & Founder and CEO
# Co-Founder and Marketing
# Co-Founder and Senior Technical Advisor
# Co-Founder and Senior Technical Advisor
# Co-Founder | Vice President of Product Development
# Consultant to the CIO
# Consultant to the CIO
# Managing Director and General Manager - Product Development
# Global Program Manager
# Co-Founder & Chief Client Officer
#  Revenue & Partnerships
# Research Fellow & Senior Analyst
# SVP - Analytics & Insight (Acquired Metaresolver)
# VP - People
# VP New Ventures (Acquired Datasnap.io)
# Chief Operating Officer & Head of Business
# Co-founder & Chief Merchandising Officer
# Director of Content & Community
# Lecturer in Management
#  Center for Entrepreneurial Studies
# Business Advisory Council Member
# CTO and Product Lead
#  Editorial and Design Lead
# International Risk Management and Senior Risk Advisor
# Strategy Lead
# Aircraft Electrician
# Co-Founder & Sales Ops
# Co-Founder & Sales Ops
# Co-Founder and Head Of Finance
# Co-Founder and Head Of Finance
#  Director of Finance and Administration
# Co-Founder & Board Of Directors
# VP of Research and Development & Co-Founder
# Director of Publisher Development
# VP - Growth
# Manager of Mobile Monetization
# CEO / Cofounder
# Chariman & CEO
# Chief Executive
#  Global Engineering
#  Chief Marketing Officer and Chief Product Officer
#  CEO and Member Services
# Producer & Founder
#  Fixed Income Capital Markets
# Co-Founder & Senior Vice President of Business Development
# Co-Founder | VP of Customer Success
# Strategy | Growth | Product
# Co-Founder & Chief Retail Officer
# MIT Corporation Development Committee - Associate Member
# MIT Corporation Development Committee - Associate Member
# Volunteer Consultant
#  President & Chief Strategy Office
# Founder / Executive Director
# Head of Risk Management and Analytics
# Runway Entrepreneur
# Chief Commercial Officer & Head of Corporate Partnerships
# Founder&President
# Mergers & Acquistions
# Office of the Chairman
# Class of 2013
# Co-founder & Operations Lead
# Corporate Development / M&A
# Senior Director of Corporate Development
# Sr. Financial Research Analyst
# VP Strategic & Corporate Development
# Director of Technology Innovation
# Founder & Team Lead - Honey
# Full-Stack Engineer and Senior Frontend Engineer
# Director of Strategy & Business Operations
# Co-Founder & Product Design Manager
# User Interface Designer (UX/UI)
# Co-founder and SVP
# Co - Founder and Lead Developer
#  Head of Product and Marketing
# Product Acceleration (M&A and Investing)
# SVP of Marketing Growth
# Vice-President of Product and Marketing
# Analytic Scientist
#  Avatar Team
# AI Advisor
# Product Marketing Lead
# Technical Product Marketing Mgr
# Management 100 TA
# Senior Investment Associate
# Co-Founder - Head of Demand Generation
# Instructor In Medicine
# Resident Physician
# Bank Accountant
#  developer and publisher of mobile apps
#  and Technical Manager
# Co - Founder & Owner
# Co - Founder & Owner
# Co - Founder & Owner
# Co - Founder & Owner
# Restructuring Professional
# Managing Director of Services & Co-Founder
# Energy Consultant
# Operations & Community
#  Chief Scientific Officer & Executive VP
#  Emerging Business
# VP of Product and Data
# Co-Founder & Head of Product
# CEO & Co-Founder at Clarity
# Chief Instigator
#  Guest Lecturer and Judge in Entrepreneurship
#  Marketing & Advertising
# VP & General Manager of Global Product
# Director of Software Operations
#  Fintech
# Chief Mentor & Founder
# Senior Vice President of Technology & CIO
# VP of Internet Division
# Co-Founder & Chief Investment Officer
# Co-founder & Chief Compliance Officer
# Led the Technology Development Group at Stanford Genome Technology Center
# Led the Technology Development Group at Stanford Genome Technology Center
# Sr Director of Diagnostics Research
# Sr Director of Diagnostics Research
#  Investment Professional
# Founder + General Partner
# Head of Dock and Remote Ops
# Senior VP of Applications
#  Chief Operating Officer & Chief Marketing Officer
# Founder & Board
# Brand Czar
# Tech Lead and Principle Software Engineer II
#  and Principal Investigator
# Head of Operations Program Management
# Head of Strategic Initiatives
# Co-Founder and Project Coordinator
# Director Workforce Management EMEA
# Co Founder & Marketing Director
# People Operations Associate
# Head of Productt
# Incubated
# Python Developer / UX Designer
# User Experience Consultant
# Data Science Lead
# Co-Founder & Business Lead
# Founder & Biology Lead
# CEO - Bow and Drape
# Business and Technology Advisor
# Director of Product / Staff Physician
# Mathematical Programmer
# Director of Strategy & Leadership
# Founder and Innovation Leader
# Chicago Team
# Global Head of Health & Wellness
# Product Development Consultant
# Product Development Consultant
# Focused on Creating Simple Technology Solutions
# Purchased Material Quality Engineer
# Purchased Material Quality Engineer
# Channel & Partner Manager
# Community Citizen & National Sales Specialist
#  Executive Manager
# Head Of Childcare Benefits
# VP Finance
# Vice President – Marketing and Business Development
# IB Operations Architect
# Founding Team & Now Advisor
# Head of Product and Strategy
# Team Member and Co-founder
# VP of Product and Strategy
#  Product and Strategy
# Chief Performance Architect
# Co-Founder & Director of Hardware Engineering
# Brand consultant
# Co-founder VP R&D
# Co-founder/Design
# Creative and Marketing Assitant
# Director- Interface Design
# Founder and Associate Partner
# Founder and Fund Manager
#  solo sciences inc.
# Investor and VP Business Development
# Investor and VP Product Management
# Leadership Analyst
#  South Asia
# MTS Mathematical Sciences
#  Cambridge Advanced Technology Lab
# Northeast ACIS Marketing Product Specialist
#  Consumer Insights
# Special Advisor to the CEO
# VP Research and Development
# VP Research and Development
# co-Founder and VP Product
# Data & Consumer Analyst
# Former President
#  CEO and founder of NetRatings
# Product and Engineering
#  AI Science
# Vice President at Hitachi Computer Products
# Chief Storage Strategist
#  VP of Operations & Products
# Head Of Research And Development
# Academy of Communication in Healthcare Faculty-In-Training Program
# Emergency Medicine Physician
# Pediatric Emergency Medicine Fellow
# Marketing Associate - LIFE
#  LIFE.com
# Advisor (Former SVP of International Partnerships)
# Co - Founder & Regional CFO - Latin America
# Co-Founder & CEO - Argentina
# Founder / SVP EMEA
# Founder / SVP EMEA
# Founder @ Academic Capital Exchange
# SVP EMEA / Founder
# SVP EMEA / Founder
# VP of Growth & Revenue
# Distinguished Engineer/Director
# Founder / CEO (Dashboard Systems)
# Founder of Women in Technology Program
# Global Chair of Cisco Women in Science and Engineering (WISE)
# Leadership roles - Consulting
# SVP / Chief Marketing Officer
# IOT
#  ODC Program Manager
# Assistant Vice-President
# Co Founder & Chief Gaming Officer
# Co-Founder& Chief Gaming Officer
#  Co-Owner & CFO
# Account Strategist / Agency Account Manager & Global Innovation Evangelist
# CGO and Co-Founder
# Chief Investment and Growth Officer
# Founder and Podcast Host
# Int. Digital Marketing Specialist
# Int. Digital Project Manager
# Co-Creator and CEO
#  Location & Events
# Senior Advisor - Loyalty
# CLO & Chief Corporate Development Officer
# CLO & EVP Business Development
# Co-Founder & CEO OfficeExpress
# Founder & CEO of BuyNow at Buy.com
# Founder & CEO of VAULT
# Founder & President of BuyNow
# President of TechStore
# Strategic Partnerships / Advisor
# Co-Founder - CFO
# System Management Consultant
# Senior Software Design Engineer
# Software Design Engineer (Part time
#  Student)
# Software Design Engineer (Part time
#  Student)
# UI/UX Developer
# Engagement Director
# Exploring new ideas and opportunities
#  Chief Analytics Officer
#  Analytical Services
# Co-founder & Chief Evangelist
# Cofounder & CTA/CTO
# VP-Global Sales
#  Strategy and Partnerships
# Executive Medical Director
# VP Of Business Development and Legal
# Board Member: Computer Science Advisory Board
# Co-Founder (VP
#  AOL Video)
# Search Engine Marketing Analyst
# Search Engine Marketing Manager
# Founder and Lead Investor
# Principal Network Management Consultant
# Senior Strategy Architect
# Chief Operating Officer & Chief Technology Officer
# CEO (NBTel)
#  Radian6
#  Business Development and Product Management
#  Member of the Board of Directors & Executive Committee
# President - Aliant Telecom
# Blockchain and ad tech advisor
# Blockchain and ad tech advisor
# Co Founder and Board Member
# Co-founder & Product Architect
# Co-founder & Product Architect
# Co-founder & Product Architect
# Co-founder & Product Architect
# Founder and Board Memeber
# Founder and Board Memeber
# Co-Founder & CEO & Member of the Board
# Co-founder and Head
#  CTO and Member of the Board
# Founding Engineer and Senior Systems Architect
#  Salesforce ExactTarget Marketing Cloud
#  EVP Technology
#  EVP Technology
#  Boldforce
# Quality Assurance Engineer
# Quality Engineer
#  Einstein
# Sr Product Marketing Manager
# Sr Solution Engineer
# Endeavor entrepreneur
# Member - Board Of Directors
# President - Board Of Directors
# Growth Team
# Growth Team
# Co-Founder & Product Engineer
# Co-Founder/Director of Customer Success
# On Leave
# Submarine Officer
# Chief Storyteller
# General Manager / Senior Director
# Sr. Manager Business Development & Product Management
#  Consumer Products
# CTO and CO-Founder
# CTO and CO-Founder
#  Business Solutions
#  Office of the Chairman & CEO
#  Desktop Switching
# Founding Member & CEO
# Co-Founder & President of Worldwide Sales & Marketing
# Director of Biomedical Informatics at the Genomics and Pathology Services
# Director of Biomedical Informatics at the Genomics and Pathology Services
# Director of Center for Biomedical Informatics
# Director of Center for Biomedical Informatics
#  Chief Technology & Innovation Officer
#  Chief Technology & Innovation Officer
#  Developer and Director
#  Developer and Director
# Senior Director Communications
# Chief Product Officer & CTO
# Chief Product Officer & CTO
# Country Operations Manager
# Co-Founder & Chief Capital Officer
#  Board member & Executive Chairman

# %%
#Number of previous titles of founders binary grouping
number_of_prev_title_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['number_of_prev_title_of_founders'][(np.isnan(df_All_Companies_merged['number_of_prev_title_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)], [0, 25, 50, 75, 100]))
number_of_prev_title_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['number_of_prev_title_of_founders'][(np.isnan(df_All_Companies_merged['number_of_prev_title_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)], [0, 25, 50, 75, 100]))
df_All_Companies_merged['number_of_prev_title_of_founders_binary_grouping_scaling'] = float('nan')

boundaries = [number_of_prev_title_of_founders_success_quantiles[4] + 1, 
              number_of_prev_title_of_founders_success_quantiles[3], 
              0]
grouping_scale = [1,0]
for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['number_of_prev_title_of_founders'] >= boundaries[idx + 1]) & ( df_All_Companies_merged['number_of_prev_title_of_founders'] < boundaries[idx]) ,'number_of_prev_title_of_founders_binary_grouping_scaling'] = grouping_scale[idx]

    
corr_params = ['number_of_prev_title_of_founders_binary_grouping_scaling','number_of_prev_title_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2)))

bar_plot_data_1 = [len(df_All_Companies_merged['number_of_prev_title_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['number_of_prev_title_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['number_of_prev_title_of_founders'] >= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['number_of_prev_title_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['number_of_prev_title_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['number_of_prev_title_of_founders'] >= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('Experience of Founding Team')
plt.title('TREND OF SUCCESS BASED ON NUMBER OF PREVIOUS TITLES HELD BY FOUNDERS')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\number_of_prev_title_of_founders_binary_grouping_scaling.png') 
plt.show()
# Out:
# The correlation between Success and number_of_prev_title_of_founders_binary_grouping_scaling: 0.052782066160674435
# The correlation between Success and number_of_prev_title_of_founders: 0.05201187359625507
# [2704, 12083]

# %%
#Number of previous managerial titles of founders grouping
managerial_flag_number_of_prev_title_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'][(np.isnan(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)], [0, 25, 50, 75, 100]))
managerial_flag_number_of_prev_title_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'][(np.isnan(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)], [0, 25, 50, 75, 100]))
df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_grouping_scaling'] = float('nan')

boundaries = [managerial_flag_number_of_prev_title_of_founders_success_quantiles[4] + 1, 
              managerial_flag_number_of_prev_title_of_founders_success_quantiles[3], 
              managerial_flag_number_of_prev_title_of_founders_success_quantiles[2], 
              managerial_flag_number_of_prev_title_of_founders_unsuccessful_quantiles[2],
              0]
grouping_scale = [3,2,1,0]
for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'] >= boundaries[idx + 1]) & ( df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'] < boundaries[idx]) ,'managerial_flag_number_of_prev_title_of_founders_grouping_scaling'] = grouping_scale[idx]

    
corr_params = ['managerial_flag_number_of_prev_title_of_founders_grouping_scaling','managerial_flag_number_of_prev_title_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2)))

bar_plot_data_1 = [len(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'] >= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'] >= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('Managerial Experience of Founding Team')
plt.title('TREND OF SUCCESS BASED ON NUMBER OF MANAGERIAL POSITIONS HELD BY FOUNDERS')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\managerial_flag_number_of_prev_title_of_founders_grouping_scaling.png')
plt.show()
# Out:
# The correlation between Success and managerial_flag_number_of_prev_title_of_founders_grouping_scaling: 0.06082399804874746
# The correlation between Success and managerial_flag_number_of_prev_title_of_founders: 0.04753297337486562
# [3056, 5777, 7116, 12084]

# %%
#Number of previous managerial titles of founders binary grouping
managerial_flag_number_of_prev_title_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'][(np.isnan(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)], [0, 25, 50, 75, 100]))
managerial_flag_number_of_prev_title_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'][(np.isnan(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)], [0, 25, 50, 75, 100]))
df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_binary_grouping_scaling'] = float('nan')

boundaries = [managerial_flag_number_of_prev_title_of_founders_success_quantiles[4] + 1, 
              managerial_flag_number_of_prev_title_of_founders_success_quantiles[3], 
              0]
grouping_scale = [3,2,1,0]
for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'] >= boundaries[idx + 1]) & ( df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'] < boundaries[idx]) ,'managerial_flag_number_of_prev_title_of_founders_binary_grouping_scaling'] = grouping_scale[idx]

    
corr_params = ['managerial_flag_number_of_prev_title_of_founders_binary_grouping_scaling','managerial_flag_number_of_prev_title_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2)))


bar_plot_data_1 = [len(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'] >= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['managerial_flag_number_of_prev_title_of_founders'] >= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.xlabel('Managerial Experience of Founding Team')
plt.title('TREND OF SUCCESS BASED ON NUMBER OF MANAGERIAL POSITIONS HELD BY FOUNDERS')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\managerial_flag_number_of_prev_title_of_founders_binary_grouping_scaling.png')
plt.show()
# Out:
# The correlation between Success and managerial_flag_number_of_prev_title_of_founders_binary_grouping_scaling: 0.04093811242375407
# The correlation between Success and managerial_flag_number_of_prev_title_of_founders: 0.04753297337486562
# [3056, 12084]

# %%
#founders_connectedness_factor_based_on_university grouping
best_score_universities_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['best_score_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_score_universities_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)], [0, 25, 50, 75, 100]))
best_score_universities_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['best_score_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_score_universities_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)], [0, 25, 50, 75, 100]))
df_All_Companies_merged['best_score_universities_of_founders_grouping_scaling'] = float('nan')

boundaries = [best_score_universities_of_founders_success_quantiles[4] + 1, 
              best_score_universities_of_founders_success_quantiles[3], 
              best_score_universities_of_founders_success_quantiles[2], 
              best_score_universities_of_founders_unsuccessful_quantiles[2],
              0]
grouping_scale = [3,2,1,0]
for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['best_score_universities_of_founders'] >= boundaries[idx + 1]) & ( df_All_Companies_merged['best_score_universities_of_founders'] < boundaries[idx]) ,'best_score_universities_of_founders_grouping_scaling'] = grouping_scale[idx]

    
corr_params = ['best_score_universities_of_founders_grouping_scaling','best_score_universities_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2)))

bar_plot_data_1 = [len(df_All_Companies_merged['best_score_universities_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['best_score_universities_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['best_score_universities_of_founders'] >= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['best_score_universities_of_founders_grouping_scaling'][(np.isnan(df_All_Companies_merged['best_score_universities_of_founders_grouping_scaling']) == False) & (df_All_Companies_merged['best_score_universities_of_founders'] >= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.title('TREND OF SUCCESS BASED ON BEST UNIVERSITY SCORE')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\best_score_universities_of_founders_grouping_scaling.png') 
plt.show()
# Out:
# The correlation between Success and best_score_universities_of_founders_grouping_scaling: 0.05445056594870417
# The correlation between Success and best_score_universities_of_founders: 0.0522127257746984
# [1950, 4112, 4515, 8597]

# %%
#founders_connectedness_factor_based_on_university grouping
best_score_universities_of_founders_success_quantiles = (np.percentile(df_All_Companies_merged['best_score_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_score_universities_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 1)], [0, 25, 50, 75, 100]))
best_score_universities_of_founders_unsuccessful_quantiles = (np.percentile(df_All_Companies_merged['best_score_universities_of_founders'][(np.isnan(df_All_Companies_merged['best_score_universities_of_founders']) == False) & (df_All_Companies_merged['success_flag'] == 0)], [0, 25, 50, 75, 100]))
df_All_Companies_merged['best_score_universities_of_founders_binary_grouping_scaling'] = float('nan')

boundaries = [best_score_universities_of_founders_success_quantiles[4] + 1, 
              best_score_universities_of_founders_success_quantiles[2], 
              0]
grouping_scale = [1,0]
for idx in range(len(boundaries) - 1):
    df_All_Companies_merged.loc[ (df_All_Companies_merged['best_score_universities_of_founders'] >= boundaries[idx + 1]) & ( df_All_Companies_merged['best_score_universities_of_founders'] < boundaries[idx]) ,'best_score_universities_of_founders_binary_grouping_scaling'] = grouping_scale[idx]

    
corr_params = ['best_score_universities_of_founders_binary_grouping_scaling','best_score_universities_of_founders']
for param in corr_params:
    var1 = df_All_Companies_merged[param][(np.isnan(df_All_Companies_merged[param]) == False)] 
    var2 = df_All_Companies_merged['success_flag'][(np.isnan(df_All_Companies_merged[param]) == False)] 
    print('The correlation between {} and {}: {}'.format('Success',param,var1.corr(var2)))

bar_plot_data_1 = [len(df_All_Companies_merged['best_score_universities_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['best_score_universities_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['best_score_universities_of_founders'] >= rank) & (df_All_Companies_merged['success_flag'] == 1)]) for rank in boundaries[1:]]
bar_plot_data_2 = [len(df_All_Companies_merged['best_score_universities_of_founders_binary_grouping_scaling'][(np.isnan(df_All_Companies_merged['best_score_universities_of_founders_binary_grouping_scaling']) == False) & (df_All_Companies_merged['best_score_universities_of_founders'] >= rank)]) for rank in boundaries[1:]]
bar_plot_data = np.array(bar_plot_data_1)/ np.array(bar_plot_data_2)
print(bar_plot_data_2)

ind = np.arange(len(boundaries[1:]))  
width = 0.35 
 
fig = plt.subplots(figsize =(10, 7))
p1 = plt.bar(ind, bar_plot_data, width)
 
plt.ylabel('Probability')
plt.title('TREND OF SUCCESS BASED ON BEST UNIVERSITY SCORE')
plt.xticks(ind, boundaries[1:])
plt.savefig(r'Figures\best_score_universities_of_founders_binary_grouping_scaling.png') 
plt.show()
# Out:
# The correlation between Success and best_score_universities_of_founders_binary_grouping_scaling: 0.04789921486564828
# The correlation between Success and best_score_universities_of_founders: 0.0522127257746984
# [4112, 8597]
